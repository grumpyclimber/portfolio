# %% [markdown]
# AICD provides membership lounges across the capitals in Australia. Members of AICD can visit these for meetings or for work. In the below presentation we'll analyze how members from different cities and industries visit AICD lounges. We'll also look for patterns based on members occupation and check if their companies office location and its distance do the local lounge has any influence on their behavior.
#
# This notebook is divided into 5 parts:
#
# <a id='index'></a>
# 1. [Inital analysis](#eda1)
# 2. [Members visits by headquarters location](#byhq)
# 3. [Lounge visitors by industry and headquarters location](#byloc)
# 4. [Roles of AICD visitors](#roles)
# 5. [Spatial Analysis](#geo)
#
# <a id='eda1'></a>
# # 1. Inital analysis

# %%
import numpy as np 
import pandas as pd 
import geopy.distance
import matplotlib.pyplot as plt
# import plotly
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
from plotly.offline import plot, iplot, init_notebook_mode
import plotly.graph_objs as go
init_notebook_mode(connected=True)

df = pd.read_csv('members.csv')

# remove nulls and change negative avg_time to 'abs' int
df = df[~df['avg_dwell_time_in_min'].isnull()]
df['avg_dwell_time_in_min'] = abs(df['avg_dwell_time_in_min'])

# create a column with combined coordinates, and total_visits column: 
df['cords'] = tuple(zip(df['longitude'], df['latitude']))
df['total_visits'] = df['visits_sydney'] + df['visits_melbourne'] + df['visits_perth']

# remove total_visits nulls:
df = df[~(df['total_visits'] == 0) & ~(df['avg_dwell_time_in_min'] == 0)]
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
fig = px.histogram(df, x="total_visits",  color_discrete_sequence=['indigo'],title='Plot 1: Number of visits distribution')
fig.update_layout(xaxis_title_text='Number of visits')
fig.show()
fig = px.histogram(df, x="avg_dwell_time_in_min", color_discrete_sequence=['indianred'],title='Plot 2: Visits length distribution')
fig.update_layout(xaxis_title_text='Length of visits')
fig.show()
# Out:
# <div>                            <div id="1abf92c3-7ee5-457f-9755-38b7dd212522" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1abf92c3-7ee5-457f-9755-38b7dd212522")) {                    Plotly.newPlot(                        "1abf92c3-7ee5-457f-9755-38b7dd212522",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"total_visits=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"indigo","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":[24,5,119,2,1,5,20,64,3,52,3,4,1,112,33,85,16,3,66,57,6,84,21,24,18,4,47,5,4,7,38,4,73,4,70,6,100,28,48,72,61,5,38,32,40,2,17,17,62,10,5,4,4,2,2,16,6,44,3,21,2,4,3,40,3,25,4,34,23,64,5,4,15,77,63,31,16,2,14,12,1,28,45,1,4,25,17,12,102,43,32,48,1,7,55,17,29,30,69,6,28,34,35,8,2,27,2,1,47,64,10,6,1,1,23,60,6,30,80,33,15,78,1,3,44,2,55,110,4,6,113,5,7,76,4,72,44,78,71,3,66,3,38,4,34,8,12,3,8,20,35,5,11,70,34,62,20,15,98,32,3,4,13,29,61,33,59,34,6,22,30,44,3,16,3,16,101,2,63,4,4,2,100,7,4,8,20,65,2,3,8,29,19,29,37,40,16,22,5,59,9,23,93,40,50,5,1,3,7,111,103,31,50,93,5,38,3,73,133,32,54,1,2,2,19,15,7,16,73,1,5,4,3,26,59,3,2,1,76,101,21,8,4,77,19,66,35,3,61,33,6,21,11,67,36,4,5,46,66,63,57,20,19,4,35,26,2,72,17,52,30,71,41,4,4,54,57,47,4,82,29,36,32,21,75,3,46,14,15,2,112,6,14,59,104,5,13,2,28,3,4,3,1,49,74,67,5,113,21,35,7,23,4,41,27,4,5,19,49,18,17,8,3,65,66,96,14,2,20,38,15,6,3,51,43,3,11,6,7,19,73,22,57,40,54,46,19,30,27,1,109,8,53,39,6,3,3,5,15,1,5,62,12,7,4,3,16,109,92,105,2,4,71,80,4,20,4,10,5,34,2,19,76,114,7,120,68,4,3,3,7,74,59,65,5,3,5,33,92,49,76,37,36,21,5,109,62,7,95,37,45,59,20,59,25,4,2,23,70,20,5,26,3,63,1,32,12,24,66,1,22,32,7,33,14,16,17,55,34,98,5,19,30,4,1,1,5,106,70,57,42,4,1,8,7,5,1,5,55,2,54,18,24,98,5,58,24,55,44,19,2,22,15,25,55,43,54,2,27,26,59,5,6,43,7,29,19,60,29,5,13,97,45,31,5,4,39,2,24,4,2,4,34,7,1,8,3,35,36,43,3,5,54,114,2,112,114,49,14,71,103,6,2,41,5,18,15,40,6,5,47,60,39,9,7,63,38,3,16,21,8,3,65,54,12,5,19,12,3,88,80,24,121,20,57,22,74,1,65,36,32,31,35,4,5,34,88,13,35,101,3,90,90,7,2,19,12,63,8,2,69,53,38,113,2,1,4,56,43,2,26,3,52,3,2,34,43,51,5,4,30,28,46,37,15,88,23,27,35,6,6,23,78,56,50,35,9,21,5,47,36,41,29,3,101,76,54,16,1,120,20,32,5,2,31,23,23,51,4,14,3,74,4,33,25,4,10,6,62,118,38,4,23,12,108,33,4,1,114,22,3,5,5,5,3,100,49,30,7,5,24,110,31,32,68,29,13,53,4,49,5,6,17,16,12,68,98,25,6,7,35,52,67,77,36,76,110,5,27,3,76,1,5,69,65,20,29,3,17,16,77,22,6,77,4,14,92,75,117,31,15,7,4,17,19,21,58,5,22,31,8,34,6,5,3,46,6,15,9,29,13,5,11,4,40,3,6,39,2,106,34,5,49,44,100,70,66,6,3,48,19,4,13,81,38,43,6,39,12,19,18,21,14,2,14,32,9,3,4,23,4,2,3,72,57,89,18,42,30,7,4,16,6,40,21,5,15,66,6,50,8,5,33,70,92,99,4,1,1,18,45,3,29,4,67,38,48,3,33,113,11,2,4,117,19,3,82,38,8,52,6,29,20,33,9,4,5,68,40,66,20,10,61,29,14,8,3,15,13,32,38,17,68,102,8,69,15,14,70,54,39,3,25,5,50,4,117,98,6,15,1,1,42,69,30,88,17,43,16,9,70,48,5,5,107,47,9,1,73,66,77,35,21,14,70,68,1,27,16,7,5,16,80,20,24,1,105,51,74,56,64,5,71,67,25,40,53,29,118,5,4,66,61,6,14,34,5,9,72,73,1,22,4,71,6,25,120,78,3,94,50,81,56,60,5,33,109,56,10,115,57,46,107,22,54,4,28,4,46,4,18,6,77,40,1,4,20,3,96,53,3,74,62,17,43,14,60,40,4,4,7,1,3,1,9,6,58,23,43,7,4,56,35,5,35,18,29,6,2,5,3,65,3,34,3,3,10,114,45,4,10,3,17,5,38,43,3,5,14,38,46,36,56,79,19,6,45,104,20,4,50,32,7,79,4,38,64,67,40,2,2,42,20,65,2,22,36,2,4,1,56,33,67,18,108,4,105,60,3,33,32,6,40,59,3,4,2,33,61,98,3,109,45,5,47,15,7,42,6,30,19,57,23,4,2,67,67,3,70,5,60,25,40,58,108,17,120,75,19,20,4,51,46,69,26,5,41,17,98,3,19,1,69,71,42,19,24,2,1,6,18,56,37,44,3,1,17,6,56,3,24,52,74,5,4,43,16,104,6,5,5,53,22,65,5,22,1,40,2,61,7,67,4,4,4,82,24,6,3,5,48,53,40,37,49,6,22,4,30,107,5,34,28,62,1,23,20,52,3,1,2,6,5,59,2,41,16,3,5,2,12,11,30, ...
# <div>                            <div id="19974c62-6c4a-4fc3-971b-197165320a2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19974c62-6c4a-4fc3-971b-197165320a2c")) {                    Plotly.newPlot(                        "19974c62-6c4a-4fc3-971b-197165320a2c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"avg_dwell_time_in_min=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"indianred","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":[139.0,121.0,180.0,84.0,172.0,155.0,168.0,51.0,99.0,133.0,151.0,234.0,168.0,225.0,354.0,126.0,16.0,158.0,46.0,139.0,268.0,45.0,105.0,4.0,152.0,127.0,286.0,83.0,253.0,90.0,288.0,8.0,138.0,234.0,66.0,1.0,90.0,238.0,118.0,85.0,7.0,239.0,7.0,73.0,157.0,131.0,94.0,139.0,150.0,149.0,75.0,136.0,8.0,206.0,229.0,91.0,53.0,183.0,347.0,44.0,52.0,113.0,201.0,135.0,230.0,61.0,41.0,176.0,106.0,91.0,112.0,167.0,44.0,145.0,139.0,191.0,158.0,138.0,112.0,109.0,126.0,89.0,249.0,26.0,236.0,185.0,75.0,172.0,55.0,234.0,21.0,89.0,78.0,76.0,207.0,99.0,277.0,14.0,179.0,193.0,65.0,45.0,59.0,93.0,144.0,164.0,155.0,61.0,75.0,175.0,248.0,56.0,90.0,138.0,39.0,170.0,319.0,108.0,144.0,86.0,25.0,177.0,148.0,129.0,89.0,70.0,41.0,268.0,218.0,41.0,174.0,259.0,175.0,131.0,98.0,42.0,101.0,267.0,18.0,302.0,45.0,228.0,12.0,111.0,134.0,101.0,258.0,69.0,71.0,15.0,197.0,42.0,3.0,154.0,97.0,38.0,103.0,258.0,161.0,142.0,169.0,137.0,179.0,66.0,147.0,66.0,97.0,64.0,169.0,71.0,93.0,211.0,46.0,110.0,39.0,225.0,124.0,137.0,18.0,153.0,73.0,155.0,176.0,54.0,24.0,73.0,87.0,177.0,224.0,137.0,145.0,88.0,34.0,77.0,18.0,38.0,34.0,243.0,37.0,224.0,95.0,141.0,135.0,239.0,146.0,175.0,169.0,176.0,197.0,28.0,187.0,310.0,123.0,168.0,136.0,203.0,46.0,31.0,137.0,21.0,296.0,80.0,103.0,64.0,36.0,122.0,78.0,58.0,28.0,129.0,7.0,261.0,67.0,64.0,286.0,122.0,105.0,142.0,268.0,247.0,123.0,77.0,164.0,117.0,179.0,51.0,136.0,39.0,43.0,67.0,172.0,34.0,72.0,185.0,17.0,149.0,105.0,176.0,173.0,262.0,207.0,238.0,54.0,71.0,101.0,230.0,125.0,166.0,4.0,246.0,211.0,178.0,93.0,131.0,149.0,53.0,225.0,130.0,87.0,131.0,317.0,116.0,209.0,237.0,127.0,125.0,259.0,120.0,119.0,226.0,136.0,255.0,93.0,33.0,124.0,73.0,70.0,91.0,246.0,92.0,66.0,253.0,98.0,248.0,102.0,91.0,272.0,342.0,145.0,261.0,20.0,231.0,180.0,145.0,9.0,143.0,93.0,364.0,136.0,50.0,167.0,132.0,298.0,75.0,118.0,30.0,150.0,127.0,137.0,132.0,333.0,143.0,200.0,159.0,97.0,309.0,165.0,212.0,37.0,117.0,95.0,216.0,141.0,247.0,204.0,132.0,104.0,126.0,76.0,146.0,100.0,65.0,162.0,187.0,153.0,39.0,52.0,208.0,183.0,186.0,178.0,59.0,158.0,219.0,242.0,38.0,178.0,66.0,165.0,47.0,326.0,168.0,19.0,137.0,186.0,71.0,161.0,1.0,131.0,234.0,107.0,43.0,135.0,155.0,56.0,147.0,15.0,158.0,282.0,28.0,163.0,220.0,268.0,62.0,147.0,92.0,93.0,64.0,249.0,25.0,129.0,128.0,27.0,189.0,140.0,10.0,203.0,165.0,249.0,156.0,159.0,148.0,140.0,225.0,102.0,204.0,144.0,180.0,11.0,175.0,429.0,25.0,269.0,207.0,85.0,186.0,179.0,262.0,168.0,113.0,6.0,114.0,135.0,79.0,139.0,106.0,14.0,163.0,297.0,101.0,263.0,110.0,71.0,146.0,39.0,143.0,111.0,31.0,17.0,228.0,244.0,187.0,222.0,69.0,106.0,57.0,214.0,92.0,34.0,236.0,18.0,90.0,66.0,7.0,18.0,97.0,6.0,15.0,21.0,321.0,180.0,61.0,272.0,118.0,31.0,329.0,248.0,116.0,50.0,111.0,139.0,103.0,294.0,84.0,94.0,231.0,86.0,30.0,91.0,118.0,94.0,127.0,34.0,17.0,4.0,259.0,131.0,117.0,212.0,26.0,92.0,167.0,213.0,226.0,212.0,88.0,285.0,146.0,21.0,320.0,230.0,31.0,3.0,59.0,82.0,230.0,98.0,104.0,215.0,67.0,275.0,214.0,186.0,107.0,66.0,9.0,46.0,267.0,221.0,135.0,245.0,243.0,245.0,209.0,275.0,81.0,14.0,185.0,253.0,8.0,37.0,88.0,358.0,130.0,2.0,64.0,110.0,157.0,135.0,161.0,191.0,121.0,120.0,52.0,106.0,10.0,28.0,268.0,132.0,178.0,151.0,72.0,24.0,105.0,92.0,86.0,6.0,189.0,17.0,46.0,184.0,102.0,133 ...

# %%
fig = make_subplots(1, 2, specs=[[{'type':'domain'},{'type':'domain'}]],
                    subplot_titles=['Members job roles', 'Members HQ locations'])


fig.add_trace(go.Pie( values=df.groupby('role')['role'].count(), 
                     labels=['CEO','Chair','Exec Director','Non-Exec Director'] ,textinfo='label+percent', legendgroup = '1'), 1, 1)
fig.update_traces(marker=dict(colors=['#AB63FA', '#FFA15A', '#19D3F3','#FF6692']))

fig.add_trace(go.Pie(labels=df.groupby('headquarter_location')['role'].count().index, values=df.groupby('headquarter_location')['role'].count(),
                    textinfo='label+percent', legendgroup = '2'), 1, 2)

fig.update_layout(title_text='Plot 3: Member numbers by role and their headquarters location',legend_tracegroupgap = 80)
fig.show()
# Out:
# <div>                            <div id="03bca6fe-e0a3-48da-928d-b77cd608db0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03bca6fe-e0a3-48da-928d-b77cd608db0b")) {                    Plotly.newPlot(                        "03bca6fe-e0a3-48da-928d-b77cd608db0b",                        [{"domain":{"x":[0.0,0.45],"y":[0.0,1.0]},"labels":["CEO","Chair","Exec Director","Non-Exec Director"],"legendgroup":"1","marker":{"colors":["#AB63FA","#FFA15A","#19D3F3","#FF6692"]},"textinfo":"label+percent","type":"pie","values":[1556,786,906,1036]},{"domain":{"x":[0.55,1.0],"y":[0.0,1.0]},"labels":["Melbourne","Perth","Sydney"],"legendgroup":"2","textinfo":"label+percent","type":"pie","values":[1354,1034,1896]}],                        {"annotations":[{"font":{"size":16},"showarrow":false,"text":"Members job roles","x":0.225,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Members HQ locations","x":0.775,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"}],"legend":{"tracegroupgap":80},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777 ...

# %% [markdown]
# * large group of AICD members visited the lounges less than 20 times
#     * plot 1 is right skewed with a very high concentration at its beginning on the left side
# * the most popular meeting time is around 2 hours
# * The most common job title among AICD members is a CEO followed by Non-Executive Director
# * Sydney-based members dominate AICD lounges, followed by Melbourne and Perth.

# %%
# AICD lounge locations:
coords_syd = (-33.86336382479448, 151.20641568508086)
coords_melb = (-37.81651586387018, 144.96262374491673)
coords_perth = (-31.955428859202144, 115.85814550988445)

# divide the dataset based on hq location:
hq_syd = df[df['headquarter_location'] == 'Sydney'].copy()
hq_melb = df[df['headquarter_location'] == 'Melbourne'].copy()
hq_perth = df[df['headquarter_location'] == 'Perth'].copy()

# calculate distances members hq to aicd lounge:
hq_syd['sydney_distance'] = hq_syd['cords'].apply(lambda x: geopy.distance.distance(x, coords_syd).km)
hq_melb['melb_distance'] = hq_melb['cords'].apply(lambda x: geopy.distance.distance(x, coords_melb).km)
hq_perth['perth_distance'] = hq_perth['cords'].apply(lambda x: geopy.distance.distance(x, coords_perth).km)

# %% [markdown]
# <a id='byhq'></a>
# # 2. Members visits by headquarters location
# [back to top](#index)

# %%
fig = go.Figure(data=[
    go.Bar(name='Visits made to city', x=['Sydney','Melbourne','Perth'], y=df[['visits_sydney','visits_melbourne','visits_perth']].sum()),
    go.Bar(name='Visits made from city', x=['Melbourne','Perth','Sydney'], y=df.groupby('headquarter_location')['total_visits'].sum()),

])

fig.update_layout(
    title='Plot 4: Number of visits to and from each city',
    yaxis=dict(title='Number of all visits'),
    xaxis=dict(title='City')
)
fig.show()
# Out:
# <div>                            <div id="bdb40a59-15ca-4cb5-b8cb-44772c56b953" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bdb40a59-15ca-4cb5-b8cb-44772c56b953")) {                    Plotly.newPlot(                        "bdb40a59-15ca-4cb5-b8cb-44772c56b953",                        [{"name":"Visits made to city","type":"bar","x":["Sydney","Melbourne","Perth"],"y":[56651,35149,41341]},{"name":"Visits made from city","type":"bar","x":["Melbourne","Perth","Sydney"],"y":[43456,37396,52289]}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinew ...
#
# var gd = document.getElementById('bdb40a59-15ca-4cb5-b8cb-44772c56b

# %%
# create a temp df for plotly:
syd = hq_syd[['visits_sydney','visits_melbourne','visits_perth']].sum().to_frame(name='hq_sydney')
melb =  hq_melb[['visits_sydney','visits_melbourne','visits_perth']].sum().to_frame(name='hq_melbourne')
perth = hq_perth[['visits_sydney','visits_melbourne','visits_perth']].sum().to_frame(name='hq_perth')
plot3 = pd.concat([syd,melb,perth], axis=1)
plot3 = plot3.transpose()

labels_x = ['HQ in Sydney', 'HQ in Melbourne', 'HQ in Perth']
fig = go.Figure(data=[
    go.Bar(name='to Sydney', x=labels_x, y=plot3['visits_sydney']),
    go.Bar(name='to Melbourne', x=labels_x, y=plot3['visits_melbourne']),
    go.Bar(name='to Perth', x=labels_x, y=plot3['visits_perth']),
])

fig.update_layout(
    title='Plot 5: Visits by members headquarters location and destination',
    yaxis=dict(title='Number of visits'),
    xaxis=dict(title='HQ City'),
    barmode='group'
)
fig.show()
# Out:
# <div>                            <div id="35b9a5d7-3544-47e8-bccf-270fe066b7f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35b9a5d7-3544-47e8-bccf-270fe066b7f0")) {                    Plotly.newPlot(                        "35b9a5d7-3544-47e8-bccf-270fe066b7f0",                        [{"name":"to Sydney","type":"bar","x":["HQ in Sydney","HQ in Melbourne","HQ in Perth"],"y":[29014,15801,11836]},{"name":"to Melbourne","type":"bar","x":["HQ in Sydney","HQ in Melbourne","HQ in Perth"],"y":[11638,11724,11787]},{"name":"to Perth","type":"bar","x":["HQ in Sydney","HQ in Melbourne","HQ in Perth"],"y":[11637,15931,13773]}],                        {"barmode":"group","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlin ...

# %%
hq_labels=['to Sydney','to Melbourne','to Perth']

fig = make_subplots(1, 3, specs=[[{'type':'domain'},{'type':'domain'}, {'type':'domain'}]],
                    subplot_titles=['HQ in Sydney', 'HQ in Melbourne','HQ in Perth'])
fig.add_trace(go.Pie(labels=hq_labels, values=hq_syd[['visits_sydney','visits_melbourne','visits_perth']].sum(), scalegroup='one',
                     textinfo='label+percent',name="HQ in Sydney"), 1, 1)
fig.add_trace(go.Pie(labels=hq_labels, values=hq_melb[['visits_sydney','visits_melbourne','visits_perth']].sum(), scalegroup='one',
                     textinfo='label+percent',name="HQ in Melbourne"), 1, 2)
fig.add_trace(go.Pie(labels=hq_labels, values=hq_perth[['visits_sydney','visits_melbourne','visits_perth']].sum(), scalegroup='one',
                     textinfo='label+percent',name="HQ in Perth"), 1, 3)

fig.update_layout(title_text='Plot 6: Share of visits')
fig.show()
# Out:
# <div>                            <div id="ae21812a-f831-4bcb-9296-fe001a93d635" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae21812a-f831-4bcb-9296-fe001a93d635")) {                    Plotly.newPlot(                        "ae21812a-f831-4bcb-9296-fe001a93d635",                        [{"domain":{"x":[0.0,0.2888888888888889],"y":[0.0,1.0]},"labels":["to Sydney","to Melbourne","to Perth"],"name":"HQ in Sydney","scalegroup":"one","textinfo":"label+percent","type":"pie","values":[29014,11638,11637]},{"domain":{"x":[0.35555555555555557,0.6444444444444445],"y":[0.0,1.0]},"labels":["to Sydney","to Melbourne","to Perth"],"name":"HQ in Melbourne","scalegroup":"one","textinfo":"label+percent","type":"pie","values":[15801,11724,15931]},{"domain":{"x":[0.7111111111111111,1.0],"y":[0.0,1.0]},"labels":["to Sydney","to Melbourne","to Perth"],"name":"HQ in Perth","scalegroup":"one","textinfo":"label+percent","type":"pie","values":[11836,11787,13773]}],                        {"annotations":[{"font":{"size":16},"showarrow":false,"text":"HQ in Sydney","x":0.14444444444444446,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"HQ in Melbourne","x":0.5,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"HQ in Perth","x":0.8555555555555556,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"}],"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777777777 ...

# %% [markdown]
# ## Table 1: Members average visit numbers by their origin and destination

# %%
dframe_list = []
for dframe in [hq_syd,hq_melb,hq_perth]:
    dframe_list.append(dframe[['visits_sydney', 'visits_melbourne', 'visits_perth','total_visits']].mean())

pd.concat(dframe_list,axis=1).rename(columns={0:'Members with Sydney HQ',1:'Members with Melbourne HQ',2:'Members with Perth HQ'})
# Out:
#                   Members with Sydney HQ  Members with Melbourne HQ  \
# visits_sydney                  15.302743                  11.669867
# visits_melbourne                6.138186                   8.658789
# visits_perth                    6.137658                  11.765879
# total_visits                   27.578586                  32.094535
#
#                   Members with Perth HQ
# visits_sydney                 11.446809
# visits_melbourne              11.399420
# visits_perth                  13.320116
# total_visits                  36.166344

# %% [markdown]
# * **Sydney-based members are the most loyal to their city** - they have the highest average number of visits in their headquarters city ~15 visits - (55.5% of their visits is within Sydney)
#     * they're also the least likely to leave their city
# * Perth-based members are most likely to visit Perth, those visits are not as dominant as in Sydney's case. Only 36.8% of their visits (on average 13.3 visits) are in Perth, followed closely by Sydney and Melbourne
# * **Melbourne is the only city, which members don't favor their lounge**, Only 27% of Melbourne-based members visit Melbourne lounge (average of 8.7 visits). Both Perth and Sydney lounges are preferable for Melbourne-based members.

# %% [markdown]
# <a id='byloc'></a>
# # 3. Lounge visitors by industry and hq
# [back to top](#index)
# ### Table 2: Total visits by industry

# %%
cm = sns.light_palette("blue", as_cmap=True)
df.groupby('industry')['total_visits'].sum().sort_values(ascending=False).to_frame(name='Total Visits').style.background_gradient(cmap=cm, axis=0)
# Out:
# <style  type="text/css" >
# #T_85cf0ff0_6160_11ec_9429_c4b301d3622frow0_col0{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_85cf0ff0_6160_11ec_9429_c4b301d3622frow1_col0{
#             background-color:  #5151fb;
#             color:  #f1f1f1;
#         }#T_85cf0ff0_6160_11ec_9429_c4b301d3622frow2_col0{
#             background-color:  #5f5ffa;
#             color:  #000000;
#         }#T_85cf0ff0_6160_11ec_9429_c4b301d3622frow3_col0{
#             background-color:  #6868fa;
#             color:  #000000;
#         }#T_85cf0ff0_6160_11ec_9429_c4b301d3622frow4_col0{
#             background-color:  #b8b8f6;
#             color:  #000000;
#         }#T_85cf0ff0_6160_11ec_9429_c4b301d3622frow5_col0{
#             background-color:  #c5c5f5;
#             color:  #000000;
#         }#T_85cf0ff0_6160_11ec_9429_c4b301d3622frow6_col0{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }</style><table id="T_85cf0ff0_6160_11ec_9429_c4b301d3622f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Visits</th>    </tr>    <tr>        <th class="index_name level0" >industry</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_85cf0ff0_6160_11ec_9429_c4b301d3622flevel0_row0" class="row_heading level0 row0" >Financials</th>
#                         <td id="T_85cf0ff0_6160_11ec_9429_c4b301d3622frow0_col0" class="data row0 col0" >20371</td>
#             </tr>
#             <tr>
#                         <th id="T_85cf0ff0_6160_11ec_9429_c4b301d3622flevel0_row1" class="row_heading level0 row1" >Health Care</th>
#                         <td id="T_85cf0ff0_6160_11ec_9429_c4b301d3622frow1_col0" class="data row1 col0" >19521</td>
#             </tr>
#             <tr>
#                         <th id="T_85cf0ff0_6160_11ec_9429_c4b301d3622flevel0_row2" class="row_heading level0 row2" >Telecommunication</th>
#                         <td id="T_85cf0ff0_6160_11ec_9429_c4b301d3622frow2_col0" class="data row2 col0" >19370</td>
#             </tr>
#             <tr>
#                         <th id="T_85cf0ff0_6160_11ec_9429_c4b301d3622flevel0_row3" class="row_heading level0 row3" >Media & Entertainment</th>
#                         <td id="T_85cf0ff0_6160_11ec_9429_c4b301d3622frow3_col0" class="data row3 col0" >19279</td>
#             </tr>
#             <tr>
#                         <th id="T_85cf0ff0_6160_11ec_9429_c4b301d3622flevel0_row4" class="row_heading level0 row4" >Insurance</th>
#                         <td id="T_85cf0ff0_6160_11ec_9429_c4b301d3622frow4_col0" class="data row4 col0" >18443</td>
#             </tr>
#             <tr>
#                         <th id="T_85cf0ff0_6160_11ec_9429_c4b301d3622flevel0_row5" class="row_heading level0 row5" >Energy</th>
#                         <td id="T_85cf0ff0_6160_11ec_9429_c4b301d3622frow5_col0" class="data row5 col0" >18309</td>
#             </tr>
#             <tr>
#                         <th id="T_85cf0ff0_6160_11ec_9429_c4b301d3622flevel0_row6" class="row_heading level0 row6" >Software & Services</th>
#                         <td id="T_85cf0ff0_6160_11ec_9429_c4b301d3622frow6_col0" class="data row6 col0" >17848</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Members from Sydney

# %%
colors = ['#646ffb', '#ef553b','#09cb96' ]
# who's leaving sydney?
plot5 = df[df['headquarter_location'] == 'Sydney'].groupby('industry')[['visits_melbourne','visits_perth']].sum().sort_values('visits_melbourne',ascending=False)

labels_x = ['to Perth','to Melbourne',]
fig = go.Figure(data=[
    go.Bar(name='to Melbourne', x=plot5['visits_melbourne'].index, y=plot5['visits_melbourne'],marker_color=colors[1]),
    go.Bar(name='to Perth', x=plot5['visits_perth'].index, y=plot5['visits_perth'],marker_color=colors[2])

])

fig.update_layout(
    title='Plot 7: Who is visiting from Sydney?',
    yaxis=dict(title='Number of visits', range=[0, 2500]),
    xaxis=dict(title='Industry'),
    barmode='group'
)
fig.show()
# Out:
# <div>                            <div id="4a1ffa66-e251-484d-9568-a91cc955fc66" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a1ffa66-e251-484d-9568-a91cc955fc66")) {                    Plotly.newPlot(                        "4a1ffa66-e251-484d-9568-a91cc955fc66",                        [{"marker":{"color":"#ef553b"},"name":"to Melbourne","type":"bar","x":["Financials","Health Care","Media & Entertainment","Insurance","Software & Services","Energy","Telecommunication"],"y":[1942,1780,1769,1623,1621,1462,1441]},{"marker":{"color":"#09cb96"},"name":"to Perth","type":"bar","x":["Financials","Health Care","Media & Entertainment","Insurance","Software & Services","Energy","Telecommunication"],"y":[1859,1781,1774,1662,1692,1453,1416]}],                        {"barmode":"group","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter" ...

# %% [markdown]
# ### Table 3: Sydney members visits

# %%
def df_style(val):
    return "font-weight: bold"
syd_out = hq_syd.groupby('industry')[['visits_sydney','visits_melbourne','visits_perth']].sum().sort_values('visits_melbourne',ascending=False).rename(columns={"visits_sydney":"Visits to Sydney","visits_melbourne": "Visits to Melbourne", "visits_perth": "Visits to Perth"})
syd_out.loc['TOTAL'] = syd_out[['Visits to Sydney','Visits to Melbourne','Visits to Perth']].sum()
syd_out.style.background_gradient(cmap=cm, subset=(syd_out.index[:-1],slice(None)), axis=0).applymap(df_style, subset=(syd_out.index[-1],slice(None)))
# Out:
# <style  type="text/css" >
# #T_860105c8_6160_11ec_9429_c4b301d3622frow0_col0{
#             background-color:  #4f4ffb;
#             color:  #f1f1f1;
#         }#T_860105c8_6160_11ec_9429_c4b301d3622frow0_col1,#T_860105c8_6160_11ec_9429_c4b301d3622frow0_col2,#T_860105c8_6160_11ec_9429_c4b301d3622frow1_col0{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_860105c8_6160_11ec_9429_c4b301d3622frow1_col1{
#             background-color:  #4d4dfb;
#             color:  #f1f1f1;
#         }#T_860105c8_6160_11ec_9429_c4b301d3622frow1_col2{
#             background-color:  #2a2afd;
#             color:  #f1f1f1;
#         }#T_860105c8_6160_11ec_9429_c4b301d3622frow2_col0{
#             background-color:  #6868fa;
#             color:  #000000;
#         }#T_860105c8_6160_11ec_9429_c4b301d3622frow2_col1{
#             background-color:  #5353fb;
#             color:  #f1f1f1;
#         }#T_860105c8_6160_11ec_9429_c4b301d3622frow2_col2{
#             background-color:  #2e2efd;
#             color:  #f1f1f1;
#         }#T_860105c8_6160_11ec_9429_c4b301d3622frow3_col0{
#             background-color:  #2222fd;
#             color:  #f1f1f1;
#         }#T_860105c8_6160_11ec_9429_c4b301d3622frow3_col1{
#             background-color:  #9a9af7;
#             color:  #000000;
#         }#T_860105c8_6160_11ec_9429_c4b301d3622frow3_col2{
#             background-color:  #6b6bfa;
#             color:  #000000;
#         }#T_860105c8_6160_11ec_9429_c4b301d3622frow4_col0{
#             background-color:  #c8c8f5;
#             color:  #000000;
#         }#T_860105c8_6160_11ec_9429_c4b301d3622frow4_col1{
#             background-color:  #9b9bf7;
#             color:  #000000;
#         }#T_860105c8_6160_11ec_9429_c4b301d3622frow4_col2{
#             background-color:  #5b5bfa;
#             color:  #f1f1f1;
#         }#T_860105c8_6160_11ec_9429_c4b301d3622frow5_col0,#T_860105c8_6160_11ec_9429_c4b301d3622frow6_col1,#T_860105c8_6160_11ec_9429_c4b301d3622frow6_col2{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_860105c8_6160_11ec_9429_c4b301d3622frow5_col1{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_860105c8_6160_11ec_9429_c4b301d3622frow5_col2{
#             background-color:  #ddddf4;
#             color:  #000000;
#         }#T_860105c8_6160_11ec_9429_c4b301d3622frow6_col0{
#             background-color:  #acacf6;
#             color:  #000000;
#         }#T_860105c8_6160_11ec_9429_c4b301d3622frow7_col0,#T_860105c8_6160_11ec_9429_c4b301d3622frow7_col1,#T_860105c8_6160_11ec_9429_c4b301d3622frow7_col2{
#             font-weight:  bold;
#         }</style><table id="T_860105c8_6160_11ec_9429_c4b301d3622f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Visits to Sydney</th>        <th class="col_heading level0 col1" >Visits to Melbourne</th>        <th class="col_heading level0 col2" >Visits to Perth</th>    </tr>    <tr>        <th class="index_name level0" >industry</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_860105c8_6160_11ec_9429_c4b301d3622flevel0_row0" class="row_heading level0 row0" >Financials</th>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow0_col0" class="data row0 col0" >4251</td>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow0_col1" class="data row0 col1" >1942</td>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow0_col2" class="data row0 col2" >1859</td>
#             </tr>
#             <tr>
#                         <th id="T_860105c8_6160_11ec_9429_c4b301d3622flevel0_row1" class="row_heading level0 row1" >Health Care</th>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow1_col0" class="data row1 col0" >4464</td>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow1_col1" class="data row1 col1" >1780</td>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow1_col2" class="data row1 col2" >1781</td>
#             </tr>
#             <tr>
#                         <th id="T_860105c8_6160_11ec_9429_c4b301d3622flevel0_row2" class="row_heading level0 row2" >Media & Entertainment</th>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow2_col0" class="data row2 col0" >4185</td>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow2_col1" class="data row2 col1" >1769</td>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow2_col2" class="data row2 col2" >1774</td>
#             </tr>
#             <tr>
#                         <th id="T_860105c8_6160_11ec_9429_c4b301d3622flevel0_row3" class="row_heading level0 row3" >Insurance</th>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow3_col0" class="data row3 col0" >4371</td>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow3_col1" class="data row3 col1" >1623</td>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow3_col2" class="data row3 col2" >1662</td>
#             </tr>
#             <tr>
#                         <th id="T_860105c8_6160_11ec_9429_c4b301d3622flevel0_row4" class="row_heading level0 row4" >Software & Services</th>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow4_col0" class="data row4 col0" >3925</td>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow4_col1" class="data row4 col1" >1621</td>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow4_col2" class="data row4 col2" >1692</td>
#             </tr>
#             <tr>
#                         <th id="T_860105c8_6160_11ec_9429_c4b301d3622flevel0_row5" class="row_heading level0 row5" >Energy</th>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow5_col0" class="data row5 col0" >3816</td>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow5_col1" class="data row5 col1" >1462</td>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow5_col2" class="data row5 col2" >1453</td>
#             </tr>
#             <tr>
#                         <th id="T_860105c8_6160_11ec_9429_c4b301d3622flevel0_row6" class="row_heading level0 row6" >Telecommunication</th>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow6_col0" class="data row6 col0" >4002</td>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow6_col1" class="data row6 col1" >1441</td>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow6_col2" class="data row6 col2" >1416</td>
#             </tr>
#             <tr>
#                         <th id="T_860105c8_6160_11ec_9429_c4b301d3622flevel0_row7" class="row_heading level0 row7" >TOTAL</th>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow7_col0" class="data row7 col0" >29014</td>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow7_col1" class="data row7 col1" >11638</td>
#                         <td id="T_860105c8_6160_11ec_9429_c4b301d3622frow7_col2" class="data row7 col2" >11637</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Sydney members from Financials, Health Care or Media & Entertainment are frequently visiting Melbourne and Perth lounges. They're also a common sight in Sydney lounges. It's worth noting that Sydney members from Telecommunication and Insurance sectors are also common in Sydney lounges, but they don't visit Melbourne or Perth as often.

# %% [markdown]
# # Members from Melbourne

# %%
# who's leaving Melborune?
plot6 = df[df['headquarter_location'] == 'Melbourne'].groupby('industry')[['visits_sydney','visits_perth']].sum().sort_values('visits_sydney',ascending=False)

labels_x = ['to Sydney','to Perth',]
fig = go.Figure(data=[
    go.Bar(name='to Sydney', x=plot6['visits_sydney'].index, y=plot6['visits_sydney']),
    go.Bar(name='to Perth', x=plot6['visits_perth'].index, y=plot6['visits_perth'],marker_color=colors[2])

])

fig.update_layout(
    title='Plot 8: Who is visiting from Melbourne?',
    yaxis=dict(title='Number of visits', range=[0, 2500]),
    xaxis=dict(title='Industry'),
    barmode='group'
)
fig.show()
# Out:
# <div>                            <div id="d710af39-aa42-4363-a265-0cde2ba19c5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d710af39-aa42-4363-a265-0cde2ba19c5e")) {                    Plotly.newPlot(                        "d710af39-aa42-4363-a265-0cde2ba19c5e",                        [{"name":"to Sydney","type":"bar","x":["Software & Services","Financials","Health Care","Media & Entertainment","Energy","Telecommunication","Insurance"],"y":[2456,2433,2327,2316,2182,2144,1943]},{"marker":{"color":"#09cb96"},"name":"to Perth","type":"bar","x":["Software & Services","Financials","Health Care","Media & Entertainment","Energy","Telecommunication","Insurance"],"y":[2444,2396,2385,2452,2162,2177,1915]}],                        {"barmode":"group","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlin ...

# %% [markdown]
# ### Table 4: Melbourne's members visits

# %%
melb_out = hq_melb.groupby('industry')[['visits_sydney','visits_melbourne','visits_perth']].sum().sort_values('visits_sydney',ascending=False).rename(columns={"visits_sydney":"Visits to Sydney","visits_melbourne": "Visits to Melbourne", "visits_perth": "Visits to Perth"})
melb_out.loc['TOTAL'] = melb_out[['Visits to Sydney','Visits to Melbourne','Visits to Perth']].sum()
melb_out.style.background_gradient(cmap=cm, subset=(melb_out.index[:-1],slice(None)), axis=0).applymap(df_style, subset=(melb_out.index[-1],slice(None)))
# Out:
# <style  type="text/css" >
# #T_861aa0d2_6160_11ec_9429_c4b301d3622frow0_col0,#T_861aa0d2_6160_11ec_9429_c4b301d3622frow3_col2,#T_861aa0d2_6160_11ec_9429_c4b301d3622frow5_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_861aa0d2_6160_11ec_9429_c4b301d3622frow0_col1,#T_861aa0d2_6160_11ec_9429_c4b301d3622frow6_col0,#T_861aa0d2_6160_11ec_9429_c4b301d3622frow6_col2{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_861aa0d2_6160_11ec_9429_c4b301d3622frow0_col2{
#             background-color:  #0303ff;
#             color:  #f1f1f1;
#         }#T_861aa0d2_6160_11ec_9429_c4b301d3622frow1_col0{
#             background-color:  #0a0afe;
#             color:  #f1f1f1;
#         }#T_861aa0d2_6160_11ec_9429_c4b301d3622frow1_col1{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_861aa0d2_6160_11ec_9429_c4b301d3622frow1_col2{
#             background-color:  #1919fe;
#             color:  #f1f1f1;
#         }#T_861aa0d2_6160_11ec_9429_c4b301d3622frow2_col0{
#             background-color:  #3c3cfc;
#             color:  #f1f1f1;
#         }#T_861aa0d2_6160_11ec_9429_c4b301d3622frow2_col1{
#             background-color:  #6464fa;
#             color:  #000000;
#         }#T_861aa0d2_6160_11ec_9429_c4b301d3622frow2_col2{
#             background-color:  #1d1dfe;
#             color:  #f1f1f1;
#         }#T_861aa0d2_6160_11ec_9429_c4b301d3622frow3_col0{
#             background-color:  #4141fc;
#             color:  #f1f1f1;
#         }#T_861aa0d2_6160_11ec_9429_c4b301d3622frow3_col1{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_861aa0d2_6160_11ec_9429_c4b301d3622frow4_col0{
#             background-color:  #8080f8;
#             color:  #000000;
#         }#T_861aa0d2_6160_11ec_9429_c4b301d3622frow4_col1{
#             background-color:  #8e8ef8;
#             color:  #000000;
#         }#T_861aa0d2_6160_11ec_9429_c4b301d3622frow4_col2{
#             background-color:  #8282f8;
#             color:  #000000;
#         }#T_861aa0d2_6160_11ec_9429_c4b301d3622frow5_col0,#T_861aa0d2_6160_11ec_9429_c4b301d3622frow6_col1{
#             background-color:  #9292f8;
#             color:  #000000;
#         }#T_861aa0d2_6160_11ec_9429_c4b301d3622frow5_col2{
#             background-color:  #7c7cf9;
#             color:  #000000;
#         }#T_861aa0d2_6160_11ec_9429_c4b301d3622frow7_col0,#T_861aa0d2_6160_11ec_9429_c4b301d3622frow7_col1,#T_861aa0d2_6160_11ec_9429_c4b301d3622frow7_col2{
#             font-weight:  bold;
#         }</style><table id="T_861aa0d2_6160_11ec_9429_c4b301d3622f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Visits to Sydney</th>        <th class="col_heading level0 col1" >Visits to Melbourne</th>        <th class="col_heading level0 col2" >Visits to Perth</th>    </tr>    <tr>        <th class="index_name level0" >industry</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_861aa0d2_6160_11ec_9429_c4b301d3622flevel0_row0" class="row_heading level0 row0" >Software & Services</th>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow0_col0" class="data row0 col0" >2456</td>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow0_col1" class="data row0 col1" >1405</td>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow0_col2" class="data row0 col2" >2444</td>
#             </tr>
#             <tr>
#                         <th id="T_861aa0d2_6160_11ec_9429_c4b301d3622flevel0_row1" class="row_heading level0 row1" >Financials</th>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow1_col0" class="data row1 col0" >2433</td>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow1_col1" class="data row1 col1" >1488</td>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow1_col2" class="data row1 col2" >2396</td>
#             </tr>
#             <tr>
#                         <th id="T_861aa0d2_6160_11ec_9429_c4b301d3622flevel0_row2" class="row_heading level0 row2" >Health Care</th>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow2_col0" class="data row2 col0" >2327</td>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow2_col1" class="data row2 col1" >1842</td>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow2_col2" class="data row2 col2" >2385</td>
#             </tr>
#             <tr>
#                         <th id="T_861aa0d2_6160_11ec_9429_c4b301d3622flevel0_row3" class="row_heading level0 row3" >Media & Entertainment</th>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow3_col0" class="data row3 col0" >2316</td>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow3_col1" class="data row3 col1" >1427</td>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow3_col2" class="data row3 col2" >2452</td>
#             </tr>
#             <tr>
#                         <th id="T_861aa0d2_6160_11ec_9429_c4b301d3622flevel0_row4" class="row_heading level0 row4" >Energy</th>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow4_col0" class="data row4 col0" >2182</td>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow4_col1" class="data row4 col1" >1710</td>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow4_col2" class="data row4 col2" >2162</td>
#             </tr>
#             <tr>
#                         <th id="T_861aa0d2_6160_11ec_9429_c4b301d3622flevel0_row5" class="row_heading level0 row5" >Telecommunication</th>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow5_col0" class="data row5 col0" >2144</td>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow5_col1" class="data row5 col1" >2154</td>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow5_col2" class="data row5 col2" >2177</td>
#             </tr>
#             <tr>
#                         <th id="T_861aa0d2_6160_11ec_9429_c4b301d3622flevel0_row6" class="row_heading level0 row6" >Insurance</th>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow6_col0" class="data row6 col0" >1943</td>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow6_col1" class="data row6 col1" >1698</td>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow6_col2" class="data row6 col2" >1915</td>
#             </tr>
#             <tr>
#                         <th id="T_861aa0d2_6160_11ec_9429_c4b301d3622flevel0_row7" class="row_heading level0 row7" >TOTAL</th>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow7_col0" class="data row7 col0" >15801</td>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow7_col1" class="data row7 col1" >11724</td>
#                         <td id="T_861aa0d2_6160_11ec_9429_c4b301d3622frow7_col2" class="data row7 col2" >15931</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Melbourne-based members frequently visiting Sydney and Perth come from the same industries(Software & Services, Financials, Health Care, Media & Entertainment), **interestingly members staying within Melbourne and visiting the local lounge come from different industries: Telecommunication, Health Care (the only common one), Energy and Insurance.**

# %% [markdown]
# # Members from Perth

# %%
# who's leaving Perth?
plot7 = df[df['headquarter_location'] == 'Perth'].groupby('industry')[['visits_sydney','visits_melbourne']].sum().sort_values('visits_sydney',ascending=False)

labels_x = ['to Sydney','to Melbourne',]
fig = go.Figure(data=[
    go.Bar(name='to Sydney', x=plot7['visits_sydney'].index, y=plot7['visits_sydney']),
    go.Bar(name='to Melbourne', x=plot7['visits_melbourne'].index, y=plot7['visits_melbourne'],marker_color=colors[1])

])

fig.update_layout(
    title='Plot 9: Who is visiting from Perth?',
    yaxis=dict(title='Number of visits', range=[0, 2500]),
    xaxis=dict(title='Industry'),
    barmode='group'
)
fig.show()
# Out:
# <div>                            <div id="2f61f361-298c-4d45-8867-fe2b32af1f91" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f61f361-298c-4d45-8867-fe2b32af1f91")) {                    Plotly.newPlot(                        "2f61f361-298c-4d45-8867-fe2b32af1f91",                        [{"name":"to Sydney","type":"bar","x":["Financials","Telecommunication","Insurance","Energy","Media & Entertainment","Software & Services","Health Care"],"y":[2003,1987,1734,1729,1662,1427,1294]},{"marker":{"color":"#ef553b"},"name":"to Melbourne","type":"bar","x":["Financials","Telecommunication","Insurance","Energy","Media & Entertainment","Software & Services","Health Care"],"y":[1943,2077,1741,1660,1699,1347,1320]}],                        {"barmode":"group","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"ou ...

# %% [markdown]
# ### Table 5: Perth's members visits

# %%
perth_out = hq_perth.groupby('industry')[['visits_sydney','visits_melbourne','visits_perth']].sum().sort_values('visits_sydney',ascending=False).rename(columns={"visits_sydney":"Visits to Sydney","visits_melbourne": "Visits to Melbourne", "visits_perth": "Visits to Perth"})
perth_out.loc['TOTAL'] = perth_out[['Visits to Sydney','Visits to Melbourne','Visits to Perth']].sum()
perth_out.style.background_gradient(cmap=cm, subset=(perth_out.index[:-1],slice(None)), axis=0).applymap(df_style, subset=(perth_out.index[-1],slice(None)))
# Out:
# <style  type="text/css" >
# #T_863102f0_6160_11ec_9429_c4b301d3622frow0_col0,#T_863102f0_6160_11ec_9429_c4b301d3622frow1_col1,#T_863102f0_6160_11ec_9429_c4b301d3622frow6_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_863102f0_6160_11ec_9429_c4b301d3622frow0_col1{
#             background-color:  #2a2afd;
#             color:  #f1f1f1;
#         }#T_863102f0_6160_11ec_9429_c4b301d3622frow0_col2{
#             background-color:  #5252fb;
#             color:  #f1f1f1;
#         }#T_863102f0_6160_11ec_9429_c4b301d3622frow1_col0{
#             background-color:  #0505ff;
#             color:  #f1f1f1;
#         }#T_863102f0_6160_11ec_9429_c4b301d3622frow1_col2,#T_863102f0_6160_11ec_9429_c4b301d3622frow2_col1{
#             background-color:  #6b6bfa;
#             color:  #000000;
#         }#T_863102f0_6160_11ec_9429_c4b301d3622frow2_col0{
#             background-color:  #5b5bfa;
#             color:  #f1f1f1;
#         }#T_863102f0_6160_11ec_9429_c4b301d3622frow2_col2{
#             background-color:  #adadf6;
#             color:  #000000;
#         }#T_863102f0_6160_11ec_9429_c4b301d3622frow3_col0{
#             background-color:  #5c5cfa;
#             color:  #f1f1f1;
#         }#T_863102f0_6160_11ec_9429_c4b301d3622frow3_col1{
#             background-color:  #8585f8;
#             color:  #000000;
#         }#T_863102f0_6160_11ec_9429_c4b301d3622frow3_col2{
#             background-color:  #3a3afc;
#             color:  #f1f1f1;
#         }#T_863102f0_6160_11ec_9429_c4b301d3622frow4_col0{
#             background-color:  #7474f9;
#             color:  #000000;
#         }#T_863102f0_6160_11ec_9429_c4b301d3622frow4_col1{
#             background-color:  #7878f9;
#             color:  #000000;
#         }#T_863102f0_6160_11ec_9429_c4b301d3622frow4_col2{
#             background-color:  #6464fa;
#             color:  #000000;
#         }#T_863102f0_6160_11ec_9429_c4b301d3622frow5_col0{
#             background-color:  #c3c3f5;
#             color:  #000000;
#         }#T_863102f0_6160_11ec_9429_c4b301d3622frow5_col1{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_863102f0_6160_11ec_9429_c4b301d3622frow5_col2,#T_863102f0_6160_11ec_9429_c4b301d3622frow6_col0,#T_863102f0_6160_11ec_9429_c4b301d3622frow6_col1{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_863102f0_6160_11ec_9429_c4b301d3622frow7_col0,#T_863102f0_6160_11ec_9429_c4b301d3622frow7_col1,#T_863102f0_6160_11ec_9429_c4b301d3622frow7_col2{
#             font-weight:  bold;
#         }</style><table id="T_863102f0_6160_11ec_9429_c4b301d3622f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Visits to Sydney</th>        <th class="col_heading level0 col1" >Visits to Melbourne</th>        <th class="col_heading level0 col2" >Visits to Perth</th>    </tr>    <tr>        <th class="index_name level0" >industry</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_863102f0_6160_11ec_9429_c4b301d3622flevel0_row0" class="row_heading level0 row0" >Financials</th>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow0_col0" class="data row0 col0" >2003</td>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow0_col1" class="data row0 col1" >1943</td>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow0_col2" class="data row0 col2" >2056</td>
#             </tr>
#             <tr>
#                         <th id="T_863102f0_6160_11ec_9429_c4b301d3622flevel0_row1" class="row_heading level0 row1" >Telecommunication</th>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow1_col0" class="data row1 col0" >1987</td>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow1_col1" class="data row1 col1" >2077</td>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow1_col2" class="data row1 col2" >1972</td>
#             </tr>
#             <tr>
#                         <th id="T_863102f0_6160_11ec_9429_c4b301d3622flevel0_row2" class="row_heading level0 row2" >Insurance</th>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow2_col0" class="data row2 col0" >1734</td>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow2_col1" class="data row2 col1" >1741</td>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow2_col2" class="data row2 col2" >1756</td>
#             </tr>
#             <tr>
#                         <th id="T_863102f0_6160_11ec_9429_c4b301d3622flevel0_row3" class="row_heading level0 row3" >Energy</th>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow3_col0" class="data row3 col0" >1729</td>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow3_col1" class="data row3 col1" >1660</td>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow3_col2" class="data row3 col2" >2135</td>
#             </tr>
#             <tr>
#                         <th id="T_863102f0_6160_11ec_9429_c4b301d3622flevel0_row4" class="row_heading level0 row4" >Media & Entertainment</th>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow4_col0" class="data row4 col0" >1662</td>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow4_col1" class="data row4 col1" >1699</td>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow4_col2" class="data row4 col2" >1995</td>
#             </tr>
#             <tr>
#                         <th id="T_863102f0_6160_11ec_9429_c4b301d3622flevel0_row5" class="row_heading level0 row5" >Software & Services</th>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow5_col0" class="data row5 col0" >1427</td>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow5_col1" class="data row5 col1" >1347</td>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow5_col2" class="data row5 col2" >1531</td>
#             </tr>
#             <tr>
#                         <th id="T_863102f0_6160_11ec_9429_c4b301d3622flevel0_row6" class="row_heading level0 row6" >Health Care</th>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow6_col0" class="data row6 col0" >1294</td>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow6_col1" class="data row6 col1" >1320</td>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow6_col2" class="data row6 col2" >2328</td>
#             </tr>
#             <tr>
#                         <th id="T_863102f0_6160_11ec_9429_c4b301d3622flevel0_row7" class="row_heading level0 row7" >TOTAL</th>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow7_col0" class="data row7 col0" >11836</td>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow7_col1" class="data row7 col1" >11787</td>
#                         <td id="T_863102f0_6160_11ec_9429_c4b301d3622frow7_col2" class="data row7 col2" >13773</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Once again we can observe members visiting lounges outside of their city coming from common industries (Financials, Telecommunication and Insurance). **Members staying in their local Perth lounge are usually from Health Care industry(least amount of visits outside of Perth)** and Energy sector.

# %% [markdown]
# <a id='roles'></a>
# # 4. Roles of AICD visitors
# [back to top](#index)

# %%
fig = make_subplots(1, 3, specs=[[{'type':'domain'},{'type':'domain'}, {'type':'domain'}]],
                    subplot_titles=['HQ in Sydney', 'HQ in Melbourne','HQ in Perth'])
fig.add_trace(go.Pie(labels=hq_syd.groupby('role')['visits_sydney'].count().index, values=hq_syd.groupby('role')['role'].count(), scalegroup='one',
                     name="HQ in Sydney"), 1, 1)
fig.add_trace(go.Pie(labels=hq_melb.groupby('role')['visits_melbourne'].count().index, values=hq_melb.groupby('role')['role'].count(), scalegroup='one',
                     name="HQ in Melbourne"), 1, 2)
fig.add_trace(go.Pie(labels=hq_perth.groupby('role')['visits_perth'].count().index, values=hq_perth.groupby('role')['role'].count(), scalegroup='one',
                     name="HQ in Perth"), 1, 3)

fig.update_layout(title_text='Plot 10: Member numbers by role and their headquarters location')
fig.update_traces(marker=dict(colors=['#AB63FA', '#FFA15A', '#19D3F3','#FF6692']))
fig.show()
# Out:
# <div>                            <div id="63016f88-1c09-44e4-898a-ecd3e840c05e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63016f88-1c09-44e4-898a-ecd3e840c05e")) {                    Plotly.newPlot(                        "63016f88-1c09-44e4-898a-ecd3e840c05e",                        [{"domain":{"x":[0.0,0.2888888888888889],"y":[0.0,1.0]},"labels":["CEO","Chair","Executive Director","Non-executive Director"],"marker":{"colors":["#AB63FA","#FFA15A","#19D3F3","#FF6692"]},"name":"HQ in Sydney","scalegroup":"one","type":"pie","values":[609,374,713,200]},{"domain":{"x":[0.35555555555555557,0.6444444444444445],"y":[0.0,1.0]},"labels":["CEO","Chair","Executive Director","Non-executive Director"],"marker":{"colors":["#AB63FA","#FFA15A","#19D3F3","#FF6692"]},"name":"HQ in Melbourne","scalegroup":"one","type":"pie","values":[545,128,38,643]},{"domain":{"x":[0.7111111111111111,1.0],"y":[0.0,1.0]},"labels":["CEO","Chair","Executive Director","Non-executive Director"],"marker":{"colors":["#AB63FA","#FFA15A","#19D3F3","#FF6692"]},"name":"HQ in Perth","scalegroup":"one","type":"pie","values":[402,284,155,193]}],                        {"annotations":[{"font":{"size":16},"showarrow":false,"text":"HQ in Sydney","x":0.14444444444444446,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"HQ in Melbourne","x":0.5,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"HQ in Perth","x":0.8555555555555556,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"}],"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222 ...

# %% [markdown]
# ### Table 6: Top 10 visitor types:

# %%
tot_v = df.groupby(['industry', 'headquarter_location','role'])['total_visits'].sum().to_frame(name='total visits')
tot_v2 = df.groupby(['industry', 'headquarter_location','role'])['total_visits'].count().to_frame(name='members')
tot_v3 = df.groupby(['industry', 'headquarter_location','role'])['total_visits'].mean().to_frame(name='average visits')
tot_v4 = df.groupby(['industry','headquarter_location', 'role'])['avg_dwell_time_in_min'].mean().to_frame(name='average_time')
together = pd.concat([tot_v,tot_v2,tot_v3,tot_v4],axis=1)
together.sort_values('total visits', ascending=False)[:10].style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_864b87e2_6160_11ec_9429_c4b301d3622frow0_col0,#T_864b87e2_6160_11ec_9429_c4b301d3622frow1_col3,#T_864b87e2_6160_11ec_9429_c4b301d3622frow2_col1,#T_864b87e2_6160_11ec_9429_c4b301d3622frow6_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow0_col1{
#             background-color:  #2424fd;
#             color:  #f1f1f1;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow0_col2{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow0_col3{
#             background-color:  #4242fc;
#             color:  #f1f1f1;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow1_col0{
#             background-color:  #0808ff;
#             color:  #f1f1f1;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow1_col1{
#             background-color:  #bdbdf5;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow1_col2{
#             background-color:  #3a3afc;
#             color:  #f1f1f1;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow2_col0{
#             background-color:  #2626fd;
#             color:  #f1f1f1;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow2_col2,#T_864b87e2_6160_11ec_9429_c4b301d3622frow3_col3,#T_864b87e2_6160_11ec_9429_c4b301d3622frow6_col1,#T_864b87e2_6160_11ec_9429_c4b301d3622frow9_col0{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow2_col3{
#             background-color:  #7777f9;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow3_col0{
#             background-color:  #4e4efb;
#             color:  #f1f1f1;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow3_col1{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow3_col2{
#             background-color:  #3636fc;
#             color:  #f1f1f1;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow4_col0{
#             background-color:  #8383f8;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow4_col1,#T_864b87e2_6160_11ec_9429_c4b301d3622frow8_col2{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow4_col2{
#             background-color:  #0303ff;
#             color:  #f1f1f1;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow4_col3{
#             background-color:  #9e9ef7;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow5_col0{
#             background-color:  #a7a7f7;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow5_col1,#T_864b87e2_6160_11ec_9429_c4b301d3622frow7_col0{
#             background-color:  #d5d5f4;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow5_col2{
#             background-color:  #3737fc;
#             color:  #f1f1f1;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow5_col3{
#             background-color:  #6969fa;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow6_col0{
#             background-color:  #b9b9f6;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow6_col3{
#             background-color:  #c3c3f5;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow7_col1,#T_864b87e2_6160_11ec_9429_c4b301d3622frow8_col1{
#             background-color:  #3b3bfc;
#             color:  #f1f1f1;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow7_col2{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow7_col3{
#             background-color:  #7c7cf9;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow8_col0{
#             background-color:  #ddddf4;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow8_col3{
#             background-color:  #b4b4f6;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow9_col1{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow9_col2{
#             background-color:  #2b2bfd;
#             color:  #f1f1f1;
#         }#T_864b87e2_6160_11ec_9429_c4b301d3622frow9_col3{
#             background-color:  #8181f8;
#             color:  #000000;
#         }</style><table id="T_864b87e2_6160_11ec_9429_c4b301d3622f" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total visits</th>        <th class="col_heading level0 col1" >members</th>        <th class="col_heading level0 col2" >average visits</th>        <th class="col_heading level0 col3" >average_time</th>    </tr>    <tr>        <th class="index_name level0" >industry</th>        <th class="index_name level1" >headquarter_location</th>        <th class="index_name level2" >role</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_864b87e2_6160_11ec_9429_c4b301d3622flevel0_row0" class="row_heading level0 row0" >Software & Services</th>
#                         <th id="T_864b87e2_6160_11ec_9429_c4b301d3622flevel1_row0" class="row_heading level1 row0" >Melbourne</th>
#                         <th id="T_864b87e2_6160_11ec_9429_c4b301d3622flevel2_row0" class="row_heading level2 row0" >Non-executive Director</th>
#                         <td id="T_864b87e2_6160_11ec_9429_c4b301d3622frow0_col0" class="data row0 col0" >4736</td>
#                         <td id="T_864b87e2_6160_11ec_9429_c4b301d3622frow0_col1" class="data row0 col1" >99</td>
#                         <td id="T_864b87e2_6160_11ec_9429_c4b301d3622frow0_col2" class="data row0 col2" >47.838384</td>
#                         <td id="T_864b87e2_6160_11ec_9429_c4b301d3622frow0_col3" class="data row0 col3" >145.333333</td>
#             </tr>
#             <tr>
#                         <th id="T_864b87e2_6160_11ec_9429_c4b301d3622flevel0_row1" class="row_heading level0 row1" >Media & Entertainment</th>
#                         <th id="T_864b87e2_6160_11ec_9429_c4b301d3622flevel1_row1" class="row_heading level1 row1" >Sydney</th>
#                         <th id="T_864b87e2_6160_11ec_9429_c4b301d3622flevel2_row1" class="row_heading level2 row1" >Chair</th>
#                         <td id="T_864b87e2_6160_11ec_9429_c4b301d3622frow1_col0" class="data row1 col0" >4715</td>
#                         <td id="T_864b87e2_6160_11ec_9429_c4b301d3622frow1_col1" class="data row1 col1" >61</td>
#                         <td id="T_864b87e2_6160_11ec_9429_c4b301d3622frow1_col2" class="data row1 col2" >77.295082</td>
#                         <td id="T_864b87e2_6160_11ec_9429_c4b301d3622frow1_col3" class="data row1 col3" >155.098361</td>
#             </tr>
#             <tr>
#                         <th id="T_864b87e2_6160_11ec_9429_c4b301d3622flevel0_row2" class="row_heading level0 row2" >Telecommunication</th>
#                         <th id="T_864b87e2_6160_11ec_9429_c4b301d3622flevel1_row2" class="row_heading level1 row2" >Melbourne</th>
#                         <th id="T_864b87e2_6160_11ec_9429_c4b301d3622flevel2_row2" class="row_heading level2 row2" >Non-executive Director</th>
#                         <td id="T_864b87e2_6160_11ec_9429_c4b301d3622frow2_col0" class="data row2 col0" >4632</td>
#                         <td id="T_864b87e2_6160_11ec_9429_c4b301d3622frow2_col1" class="data row2 col1" >108</td>
#                         <td id="T_864b87e2_6160_11ec_9429_c4b301d3622frow2_col2" class="data row2 col2" >42.888889</td>
#                         <td id="T_864b87e2_6160_11ec_9429_c4b301d3622frow2_col3" class="data row2 col3" >137.685185</td>
#             </tr>
#             <tr>
#                         <th id="T_864b87e2_616

# %% [markdown]
# * CEOs are a very common job title among AICD members across all 3 cities, though sometimes they're not the most popular occupation
# * Melbourne has a very high share of Non-executive Directors and very low share of Executive Directors compared to Sydney and Perth
# * Looking at the top 10 member types by total amount of visits in Table 6 we can notice that both Sydney and Perth members share the same job position (Chair), whereas members from Melbourne are always a Non-executive Director

# %%
fig = make_subplots(1, 3, specs=[[{'type':'domain'},{'type':'domain'}, {'type':'domain'}]],
                    subplot_titles=['HQ in Sydney', 'HQ in Melbourne','HQ in Perth'])
fig.add_trace(go.Pie(labels=hq_syd.groupby('role')['visits_sydney'].sum().index, values=hq_syd.groupby('role')['visits_sydney'].sum(), scalegroup='one',
                     name="HQ in Sydney"), 1, 1)
fig.add_trace(go.Pie(labels=hq_melb.groupby('role')['visits_melbourne'].sum().index, values=hq_melb.groupby('role')['visits_melbourne'].sum(), scalegroup='one',
                     name="HQ in Melbourne"), 1, 2)
fig.add_trace(go.Pie(labels=hq_perth.groupby('role')['visits_perth'].sum().index, values=hq_perth.groupby('role')['visits_perth'].sum(), scalegroup='one',
                     name="HQ in Perth"), 1, 3)

fig.update_layout(title_text='Plot 11: Share of visits by role, within the same city')
fig.update_traces(marker=dict(colors=['#AB63FA', '#FFA15A', '#19D3F3','#FF6692']))
fig.show()
fig = make_subplots(1, 3, specs=[[{'type':'domain'},{'type':'domain'}, {'type':'domain'}]],
                    subplot_titles=['HQ in Sydney', 'HQ in Melbourne','HQ in Perth'])
fig.add_trace(go.Pie(labels=hq_syd.groupby('role')[['visits_melbourne','visits_perth']].sum().sum(axis=1).index, values=hq_syd.groupby('role')[['visits_melbourne','visits_perth']].sum().sum(axis=1), scalegroup='one',
                     name="HQ in Sydney"), 1, 1)
fig.add_trace(go.Pie(labels=hq_melb.groupby('role')[['visits_sydney','visits_perth']].sum().sum(axis=1).index, values=hq_melb.groupby('role')[['visits_sydney','visits_perth']].sum().sum(axis=1), scalegroup='one',
                     name="HQ in Melbourne"), 1, 2)
fig.add_trace(go.Pie(labels=hq_perth.groupby('role')[['visits_sydney','visits_melbourne']].sum().sum(axis=1).index, values=hq_perth.groupby('role')[['visits_sydney','visits_melbourne']].sum().sum(axis=1), scalegroup='one',
                     name="HQ in Perth"), 1, 3)

fig.update_traces(marker=dict(colors=['#AB63FA', '#FFA15A', '#19D3F3','#FF6692']))
fig.update_layout(title_text='Plot 12: Share of visits outside of HQ city by role')
fig.show()
# Out:
# <div>                            <div id="f1cba409-70d7-4e69-9449-3aa750877084" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1cba409-70d7-4e69-9449-3aa750877084")) {                    Plotly.newPlot(                        "f1cba409-70d7-4e69-9449-3aa750877084",                        [{"domain":{"x":[0.0,0.2888888888888889],"y":[0.0,1.0]},"labels":["CEO","Chair","Executive Director","Non-executive Director"],"marker":{"colors":["#AB63FA","#FFA15A","#19D3F3","#FF6692"]},"name":"HQ in Sydney","scalegroup":"one","type":"pie","values":[1253,15689,7643,4429]},{"domain":{"x":[0.35555555555555557,0.6444444444444445],"y":[0.0,1.0]},"labels":["CEO","Chair","Executive Director","Non-executive Director"],"marker":{"colors":["#AB63FA","#FFA15A","#19D3F3","#FF6692"]},"name":"HQ in Melbourne","scalegroup":"one","type":"pie","values":[691,3254,240,7539]},{"domain":{"x":[0.7111111111111111,1.0],"y":[0.0,1.0]},"labels":["CEO","Chair","Executive Director","Non-executive Director"],"marker":{"colors":["#AB63FA","#FFA15A","#19D3F3","#FF6692"]},"name":"HQ in Perth","scalegroup":"one","type":"pie","values":[676,8929,1260,2908]}],                        {"annotations":[{"font":{"size":16},"showarrow":false,"text":"HQ in Sydney","x":0.14444444444444446,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"HQ in Melbourne","x":0.5,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"HQ in Perth","x":0.8555555555555556,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"}],"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f ...
# <div>                            <div id="9cab2251-7000-4147-8979-618380202f9d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9cab2251-7000-4147-8979-618380202f9d")) {                    Plotly.newPlot(                        "9cab2251-7000-4147-8979-618380202f9d",                        [{"domain":{"x":[0.0,0.2888888888888889],"y":[0.0,1.0]},"labels":["CEO","Chair","Executive Director","Non-executive Director"],"marker":{"colors":["#AB63FA","#FFA15A","#19D3F3","#FF6692"]},"name":"HQ in Sydney","scalegroup":"one","type":"pie","values":[1076,13230,5916,3053]},{"domain":{"x":[0.35555555555555557,0.6444444444444445],"y":[0.0,1.0]},"labels":["CEO","Chair","Executive Director","Non-executive Director"],"marker":{"colors":["#AB63FA","#FFA15A","#19D3F3","#FF6692"]},"name":"HQ in Melbourne","scalegroup":"one","type":"pie","values":[1813,8032,559,21328]},{"domain":{"x":[0.7111111111111111,1.0],"y":[0.0,1.0]},"labels":["CEO","Chair","Executive Director","Non-executive Director"],"marker":{"colors":["#AB63FA","#FFA15A","#19D3F3","#FF6692"]},"name":"HQ in Perth","scalegroup":"one","type":"pie","values":[1091,15044,2115,5373]}],                        {"annotations":[{"font":{"size":16},"showarrow":false,"text":"HQ in Sydney","x":0.14444444444444446,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"HQ in Melbourne","x":0.5,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"HQ in Perth","x":0.8555555555555556,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"}],"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46 ...

# %% [markdown]
# We can clearly see a big difference in members job positions based on their headquarters location. Though Sydney and Perth share some similarities: dominance of Chair in the first place, Executive Director and Non-executive Director in the second or third place. **Melbourne once again presents a very different pattern**:
# * overwhelming majority of visits by Melbourne-based members is conducted by Non-executive Directors, Chair in second place with only quarter of a share of visits (both Sydney and Perth based Chairs are responsible for more than a half of visits)
# * Melbourne-based Executive Directors are responsible for a very small fraction of visits (~2%, compared to 26% for Sydney-based and ~9% for Perth based)
# * **Interestingly each cities share of visits for each role doesn't change much between local visits and visits outside of the headquarters location**

# %% [markdown]
# ## Sydney
# ### Table 7: Sydney's members visits by their role and industry
# [table 7 summary](#tab7)

# %%
tot_v1 = hq_syd.groupby(['industry', 'role'])[['visits_sydney', 'visits_melbourne', 'visits_perth','total_visits']].sum()
tot_v2 = hq_syd.groupby(['industry', 'role'])['total_visits'].count().to_frame(name='members')
tot_v3 = hq_syd.groupby(['industry', 'role'])['total_visits'].mean().to_frame(name='average total visits')
tot_v4 = hq_syd.groupby(['industry', 'role'])['avg_dwell_time_in_min'].mean().to_frame(name='average_time')
together = pd.concat([tot_v1,tot_v2,tot_v3,tot_v4],axis=1)
together.sort_values('total_visits', ascending=False).style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_86837d14_6160_11ec_9429_c4b301d3622frow0_col0,#T_86837d14_6160_11ec_9429_c4b301d3622frow0_col1,#T_86837d14_6160_11ec_9429_c4b301d3622frow0_col2,#T_86837d14_6160_11ec_9429_c4b301d3622frow0_col3,#T_86837d14_6160_11ec_9429_c4b301d3622frow0_col6,#T_86837d14_6160_11ec_9429_c4b301d3622frow1_col0,#T_86837d14_6160_11ec_9429_c4b301d3622frow3_col5,#T_86837d14_6160_11ec_9429_c4b301d3622frow7_col4{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow0_col4,#T_86837d14_6160_11ec_9429_c4b301d3622frow9_col3{
#             background-color:  #9a9af7;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow0_col5,#T_86837d14_6160_11ec_9429_c4b301d3622frow4_col5{
#             background-color:  #0808ff;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow1_col1,#T_86837d14_6160_11ec_9429_c4b301d3622frow6_col5{
#             background-color:  #1010fe;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow1_col2,#T_86837d14_6160_11ec_9429_c4b301d3622frow2_col0,#T_86837d14_6160_11ec_9429_c4b301d3622frow2_col2{
#             background-color:  #1919fe;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow1_col3,#T_86837d14_6160_11ec_9429_c4b301d3622frow5_col5{
#             background-color:  #0a0afe;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow1_col4,#T_86837d14_6160_11ec_9429_c4b301d3622frow9_col2{
#             background-color:  #a0a0f7;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow1_col5{
#             background-color:  #0606ff;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow1_col6,#T_86837d14_6160_11ec_9429_c4b301d3622frow19_col3{
#             background-color:  #d3d3f4;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow2_col1,#T_86837d14_6160_11ec_9429_c4b301d3622frow3_col0{
#             background-color:  #1313fe;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow2_col3{
#             background-color:  #1818fe;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow2_col4{
#             background-color:  #a7a7f7;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow2_col5{
#             background-color:  #0707ff;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow2_col6{
#             background-color:  #5b5bfa;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow3_col1{
#             background-color:  #2e2efd;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow3_col2{
#             background-color:  #3939fc;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow3_col3,#T_86837d14_6160_11ec_9429_c4b301d3622frow4_col1{
#             background-color:  #2323fd;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow3_col4,#T_86837d14_6160_11ec_9429_c4b301d3622frow4_col4{
#             background-color:  #b0b0f6;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow3_col6,#T_86837d14_6160_11ec_9429_c4b301d3622frow7_col0{
#             background-color:  #7171f9;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow4_col0{
#             background-color:  #2929fd;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow4_col2,#T_86837d14_6160_11ec_9429_c4b301d3622frow5_col3{
#             background-color:  #3535fc;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow4_col3{
#             background-color:  #2a2afd;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow4_col6,#T_86837d14_6160_11ec_9429_c4b301d3622frow13_col3{
#             background-color:  #a3a3f7;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow5_col0,#T_86837d14_6160_11ec_9429_c4b301d3622frow6_col0{
#             background-color:  #2828fd;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow5_col1{
#             background-color:  #4646fb;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow5_col2,#T_86837d14_6160_11ec_9429_c4b301d3622frow10_col4{
#             background-color:  #4040fc;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow5_col4,#T_86837d14_6160_11ec_9429_c4b301d3622frow6_col4,#T_86837d14_6160_11ec_9429_c4b301d3622frow12_col2{
#             background-color:  #b4b4f6;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow5_col6{
#             background-color:  #3d3dfc;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow6_col1,#T_86837d14_6160_11ec_9429_c4b301d3622frow11_col4{
#             background-color:  #4a4afb;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow6_col2{
#             background-color:  #4e4efb;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow6_col3{
#             background-color:  #3a3afc;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow6_col6,#T_86837d14_6160_11ec_9429_c4b301d3622frow22_col1{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow7_col1,#T_86837d14_6160_11ec_9429_c4b301d3622frow27_col4{
#             background-color:  #7676f9;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow7_col2{
#             background-color:  #7e7ef9;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow7_col3{
#             background-color:  #7777f9;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow7_col5,#T_86837d14_6160_11ec_9429_c4b301d3622frow8_col5,#T_86837d14_6160_11ec_9429_c4b301d3622frow14_col2,#T_86837d14_6160_11ec_9429_c4b301d3622frow17_col0{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow7_col6,#T_86837d14_6160_11ec_9429_c4b301d3622frow16_col0{
#             background-color:  #b1b1f6;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow8_col0,#T_86837d14_6160_11ec_9429_c4b301d3622frow12_col0{
#             background-color:  #9595f7;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow8_col1,#T_86837d14_6160_11ec_9429_c4b301d3622frow14_col6{
#             background-color:  #9b9bf7;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow8_col2,#T_86837d14_6160_11ec_9429_c4b301d3622frow11_col3{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow8_col3{
#             background-color:  #9999f7;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow8_col4{
#             background-color:  #4747fb;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow8_col6{
#             background-color:  #5c5cfa;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow9_col0,#T_86837d14_6160_11ec_9429_c4b301d3622frow20_col5{
#             background-color:  #8f8ff8;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow9_col1,#T_86837d14_6160_11ec_9429_c4b301d3622frow10_col1{
#             background-color:  #a4a4f7;
#             color:  #000000;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow9_col4{
#             background-color:  #3e3efc;
#             color:  #f1f1f1;
#         }#T_86837d14_6160_11ec_9429_c4b301d3622frow9_col5,#T_86837d14_6160_11ec_9429_c4b301d3622frow10_col6,#T_86837d14_6160_11ec_9429_c4b301d3622frow12_col5,#T_86837d14_6160_11ec_9429_c4b301d3622frow18_col6{
#             background-color:  #c1c1f5;
#             color:

# %% [markdown]
# <a id='tab7'></a>
# ### Summary of table 7:
# * Sydney-based Chairs are the third biggest group in Sydney, but they have the highest number of total visits and the highest number of average visits
#     * Chairs from Telecommunication and Health Care sectors on average conduct one of the shortest visits in opposite to Chairs from Energy and Media industries (Executive Directors from Energy sector also have a very high number for their average visit time)

# %% [markdown]
# ## Melbourne
# ### Table 8: Melbourne's members visits by their role and industry
# [table 8 summary](#tab8)

# %%
tot_v1 = hq_melb.groupby(['industry', 'role'])[['visits_sydney', 'visits_melbourne', 'visits_perth','total_visits']].sum()
tot_v2 = hq_melb.groupby(['industry', 'role'])['total_visits'].count().to_frame(name='members')
tot_v3 = hq_melb.groupby(['industry', 'role'])['total_visits'].mean().to_frame(name='average total visits')
tot_v4 = hq_melb.groupby(['industry', 'role'])['avg_dwell_time_in_min'].mean().to_frame(name='average_time')
together = pd.concat([tot_v1,tot_v2,tot_v3,tot_v4],axis=1)
together.sort_values('total_visits', ascending=False).style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_868ec25a_6160_11ec_9429_c4b301d3622frow0_col0,#T_868ec25a_6160_11ec_9429_c4b301d3622frow0_col2,#T_868ec25a_6160_11ec_9429_c4b301d3622frow0_col3,#T_868ec25a_6160_11ec_9429_c4b301d3622frow1_col1,#T_868ec25a_6160_11ec_9429_c4b301d3622frow1_col4,#T_868ec25a_6160_11ec_9429_c4b301d3622frow7_col5,#T_868ec25a_6160_11ec_9429_c4b301d3622frow23_col6{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow0_col1{
#             background-color:  #6363fa;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow0_col4{
#             background-color:  #1414fe;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow0_col5{
#             background-color:  #7f7ff9;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow0_col6,#T_868ec25a_6160_11ec_9429_c4b301d3622frow1_col5{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow1_col0,#T_868ec25a_6160_11ec_9429_c4b301d3622frow3_col2{
#             background-color:  #2f2ffd;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow1_col2{
#             background-color:  #2525fd;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow1_col3{
#             background-color:  #0505ff;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow1_col6,#T_868ec25a_6160_11ec_9429_c4b301d3622frow18_col6{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow2_col0{
#             background-color:  #3b3bfc;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow2_col1{
#             background-color:  #2727fd;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow2_col2,#T_868ec25a_6160_11ec_9429_c4b301d3622frow5_col2,#T_868ec25a_6160_11ec_9429_c4b301d3622frow16_col4{
#             background-color:  #3838fc;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow2_col3{
#             background-color:  #1d1dfe;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow2_col4,#T_868ec25a_6160_11ec_9429_c4b301d3622frow3_col4{
#             background-color:  #2121fd;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow2_col5,#T_868ec25a_6160_11ec_9429_c4b301d3622frow7_col2{
#             background-color:  #8888f8;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow2_col6{
#             background-color:  #9f9ff7;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow3_col0{
#             background-color:  #3535fc;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow3_col1{
#             background-color:  #4040fc;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow3_col3{
#             background-color:  #1e1efd;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow3_col5,#T_868ec25a_6160_11ec_9429_c4b301d3622frow4_col5{
#             background-color:  #8989f8;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow3_col6{
#             background-color:  #b1b1f6;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow4_col0{
#             background-color:  #4949fb;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow4_col1,#T_868ec25a_6160_11ec_9429_c4b301d3622frow5_col3{
#             background-color:  #3030fd;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow4_col2{
#             background-color:  #4444fc;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow4_col3{
#             background-color:  #2a2afd;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow4_col4{
#             background-color:  #2c2cfd;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow4_col6,#T_868ec25a_6160_11ec_9429_c4b301d3622frow13_col2{
#             background-color:  #c5c5f5;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow5_col0,#T_868ec25a_6160_11ec_9429_c4b301d3622frow6_col1{
#             background-color:  #4747fb;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow5_col1{
#             background-color:  #5454fb;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow5_col4{
#             background-color:  #3a3afc;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow5_col5{
#             background-color:  #8383f8;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow5_col6,#T_868ec25a_6160_11ec_9429_c4b301d3622frow9_col3{
#             background-color:  #8f8ff8;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow6_col0{
#             background-color:  #5757fb;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow6_col2{
#             background-color:  #5353fb;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow6_col3{
#             background-color:  #3d3dfc;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow6_col4,#T_868ec25a_6160_11ec_9429_c4b301d3622frow19_col4{
#             background-color:  #3e3efc;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow6_col5,#T_868ec25a_6160_11ec_9429_c4b301d3622frow7_col3{
#             background-color:  #8a8af8;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow6_col6{
#             background-color:  #adadf6;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow7_col0,#T_868ec25a_6160_11ec_9429_c4b301d3622frow10_col6,#T_868ec25a_6160_11ec_9429_c4b301d3622frow12_col1{
#             background-color:  #9191f8;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow7_col1,#T_868ec25a_6160_11ec_9429_c4b301d3622frow12_col6{
#             background-color:  #acacf6;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow7_col4{
#             background-color:  #c4c4f5;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow7_col6,#T_868ec25a_6160_11ec_9429_c4b301d3622frow11_col0,#T_868ec25a_6160_11ec_9429_c4b301d3622frow21_col5,#T_868ec25a_6160_11ec_9429_c4b301d3622frow22_col5{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow8_col0{
#             background-color:  #9b9bf7;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow8_col1,#T_868ec25a_6160_11ec_9429_c4b301d3622frow21_col6{
#             background-color:  #9595f7;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow8_col2,#T_868ec25a_6160_11ec_9429_c4b301d3622frow10_col2{
#             background-color:  #9a9af7;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow8_col3,#T_868ec25a_6160_11ec_9429_c4b301d3622frow16_col6{
#             background-color:  #8e8ef8;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow8_col4,#T_868ec25a_6160_11ec_9429_c4b301d3622frow9_col4{
#             background-color:  #c1c1f5;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow8_col5{
#             background-color:  #1515fe;
#             color:  #f1f1f1;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow8_col6{
#             background-color:  #b8b8f6;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow9_col0{
#             background-color:  #a3a3f7;
#             color:  #000000;
#         }#T_868ec25a_6160_11ec_9429_c4b301d3622frow9_col1,#T_868ec25a_6160_11ec_9429_c4b301d3622fro

# %% [markdown]
# <a id='tab8'></a>
# ### Summary of table 8:
# * Melbourne-based Chairs are the third biggest group in Melbourne, but they have the highest number of average meetings not only compared to other members from Melbourne but from all the other cities as well
# * Non-executive Directors from Melbourne dominate Chairs in total number of visits
# * Continuing the trend of different patterns for Melbourne: CEOs from Melbourne visited AICD lounges more times than Executive Directors from Melbourne, this is the only example of CEOs not being on the last place.

# %% [markdown]
# ## Perth
# ### Table 9: Perth's members visits by their role and industry
# [table 9 summary](#tab9)

# %%
tot_v1 = hq_perth.groupby(['industry', 'role'])[['visits_sydney', 'visits_melbourne', 'visits_perth','total_visits']].sum()
tot_v2 = hq_perth.groupby(['industry', 'role'])['total_visits'].count().to_frame(name='members')
tot_v3 = hq_perth.groupby(['industry', 'role'])['total_visits'].mean().to_frame(name='average total visits')
tot_v4 = hq_perth.groupby(['industry', 'role'])['avg_dwell_time_in_min'].mean().to_frame(name='average_time')
together = pd.concat([tot_v1,tot_v2,tot_v3, tot_v4],axis=1)
together.sort_values('total_visits', ascending=False).style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_869ab86c_6160_11ec_9429_c4b301d3622frow0_col0,#T_869ab86c_6160_11ec_9429_c4b301d3622frow0_col3,#T_869ab86c_6160_11ec_9429_c4b301d3622frow1_col1,#T_869ab86c_6160_11ec_9429_c4b301d3622frow1_col5,#T_869ab86c_6160_11ec_9429_c4b301d3622frow5_col2,#T_869ab86c_6160_11ec_9429_c4b301d3622frow7_col6,#T_869ab86c_6160_11ec_9429_c4b301d3622frow22_col4{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow0_col1,#T_869ab86c_6160_11ec_9429_c4b301d3622frow0_col5{
#             background-color:  #0101ff;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow0_col2{
#             background-color:  #0707ff;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow0_col4{
#             background-color:  #4c4cfb;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow0_col6,#T_869ab86c_6160_11ec_9429_c4b301d3622frow6_col1{
#             background-color:  #6161fa;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow1_col0,#T_869ab86c_6160_11ec_9429_c4b301d3622frow1_col3{
#             background-color:  #0808ff;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow1_col2,#T_869ab86c_6160_11ec_9429_c4b301d3622frow24_col4{
#             background-color:  #1919fe;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow1_col4,#T_869ab86c_6160_11ec_9429_c4b301d3622frow3_col2{
#             background-color:  #5757fb;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow1_col6,#T_869ab86c_6160_11ec_9429_c4b301d3622frow10_col5,#T_869ab86c_6160_11ec_9429_c4b301d3622frow12_col5,#T_869ab86c_6160_11ec_9429_c4b301d3622frow16_col6{
#             background-color:  #7c7cf9;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow2_col0{
#             background-color:  #4b4bfb;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow2_col1{
#             background-color:  #4a4afb;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow2_col2{
#             background-color:  #2525fd;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow2_col3{
#             background-color:  #3b3bfc;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow2_col4{
#             background-color:  #8080f8;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow2_col5{
#             background-color:  #0c0cfe;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow2_col6,#T_869ab86c_6160_11ec_9429_c4b301d3622frow12_col6{
#             background-color:  #2626fd;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow3_col0,#T_869ab86c_6160_11ec_9429_c4b301d3622frow25_col4{
#             background-color:  #3d3dfc;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow3_col1{
#             background-color:  #3c3cfc;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow3_col3{
#             background-color:  #4444fc;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow3_col4,#T_869ab86c_6160_11ec_9429_c4b301d3622frow15_col6{
#             background-color:  #8f8ff8;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow3_col5{
#             background-color:  #0404ff;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow3_col6{
#             background-color:  #6363fa;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow4_col0{
#             background-color:  #5151fb;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow4_col1{
#             background-color:  #5555fb;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow4_col2{
#             background-color:  #3838fc;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow4_col3{
#             background-color:  #4848fb;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow4_col4{
#             background-color:  #8b8bf8;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow4_col5{
#             background-color:  #0f0ffe;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow4_col6{
#             background-color:  #5f5ffa;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow5_col0{
#             background-color:  #8383f8;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow5_col1{
#             background-color:  #7a7af9;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow5_col3{
#             background-color:  #5050fb;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow5_col4{
#             background-color:  #8585f8;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow5_col5{
#             background-color:  #2121fd;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow5_col6{
#             background-color:  #4242fc;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow6_col0{
#             background-color:  #5e5efa;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow6_col2{
#             background-color:  #6565fa;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow6_col3{
#             background-color:  #6060fa;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow6_col4,#T_869ab86c_6160_11ec_9429_c4b301d3622frow7_col1,#T_869ab86c_6160_11ec_9429_c4b301d3622frow9_col1{
#             background-color:  #a9a9f6;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow6_col5{
#             background-color:  #0909ff;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow6_col6{
#             background-color:  #5a5afa;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow7_col0,#T_869ab86c_6160_11ec_9429_c4b301d3622frow10_col1{
#             background-color:  #aaaaf6;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow7_col2{
#             background-color:  #a5a5f7;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow7_col3{
#             background-color:  #a8a8f6;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow7_col4{
#             background-color:  #9e9ef7;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow7_col5{
#             background-color:  #7f7ff9;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow8_col0{
#             background-color:  #b7b7f6;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow8_col1,#T_869ab86c_6160_11ec_9429_c4b301d3622frow8_col3,#T_869ab86c_6160_11ec_9429_c4b301d3622frow9_col3{
#             background-color:  #b0b0f6;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow8_col2{
#             background-color:  #ababf6;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow8_col4{
#             background-color:  #a4a4f7;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow8_col5,#T_869ab86c_6160_11ec_9429_c4b301d3622frow27_col6{
#             background-color:  #8989f8;
#             color:  #000000;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow8_col6{
#             background-color:  #2020fd;
#             color:  #f1f1f1;
#         }#T_869ab86c_6160_11ec_9429_c4b301d3622frow9_col0,#T_869ab86c_6160_11ec_9429_c4b301d3622frow11_col2{
#             background-color:  #b6b6f6;
#             color:  #000000;
#         }#T_

# %% [markdown]
# <a id='tab9'></a>
# ### Summary of table 9:
# * Perth-based Chairs registered the highest number of visits compared to workers with other roles from Perth.
#     * interestingly the Perth Chairs with the highest numbers of total visits come from Financials, Telecommunication and Energy sectors
#     * Sydney-based Chairs working in those 3 sectors have the lowest number of total visits

# %% [markdown]
# <a id='geo'></a>
# # 5. Spatial analysis
# [back to top](#index)
#
# ## Sydney

# %%
bins = np.array([0,  5, 10, 15, 20,
       25, 35, 50])

x1 = hq_syd.groupby(pd.cut(hq_syd.sydney_distance, bins))['avg_dwell_time_in_min'].count()
x2 = hq_syd.groupby(pd.cut(hq_syd.sydney_distance, bins))['total_visits'].sum()
x3 = hq_syd.groupby(pd.cut(hq_syd.sydney_distance, bins))['avg_dwell_time_in_min'].mean()
test1 = pd.concat([x1,x2,x3],axis=1)
test1.columns = ['Number of members','Total visits','Avg meeting time']
test1['Avg visits'] = test1['Total visits'] / test1['Number of members']
test1.index.names = ['Distance from Sydney\'s AICD']
test1
# Out:
#                              Number of members  Total visits  \
# Distance from Sydney's AICD
# (0, 5]                                     202          5400
# (5, 10]                                    486         13039
# (10, 15]                                   547         15445
# (15, 20]                                   364         10219
# (20, 25]                                   192          5144
# (25, 35]                                    98          2762
# (35, 50]                                     7           280
#
#                              Avg meeting time  Avg visits
# Distance from Sydney's AICD
# (0, 5]                             127.935644   26.732673
# (5, 10]                            129.876543   26.829218
# (10, 15]                           133.797075   28.235832
# (15, 20]                           130.593407   28.074176
# (20, 25]                           133.223958   26.791667
# (25, 35]                           143.612245   28.183673
# (35, 50]                            99.285714   40.000000

# %%
fig, ax = plt.subplots(figsize=(16,12))
plt.scatter(hq_syd['longitude'], hq_syd['latitude'], s=hq_syd['total_visits'], alpha=0.6, label='Members headquarters')
plt.scatter(-33.86336382479448, 151.20641568508086, s=120, label='AICD Sydney Lounge')
plt.legend()
plt.axis('off')
plt.title('Plot 13: Distance from lounge vs total visits in Sydney')
plt.show()

# %% [markdown]
# ## Melbourne

# %%
x1 = hq_melb.groupby(pd.cut(hq_melb.melb_distance, bins))['avg_dwell_time_in_min'].count()
x2 = hq_melb.groupby(pd.cut(hq_melb.melb_distance, bins))['total_visits'].sum()
x3 = hq_melb.groupby(pd.cut(hq_melb.melb_distance, bins))['avg_dwell_time_in_min'].mean()
test1 = pd.concat([x1,x2,x3],axis=1)
test1.columns = ['Number of members','Total visits','Avg meeting time']
test1['Avg visits'] = test1['Total visits'] / test1['Number of members']
test1.index.names = ['Distance from Melbourne\'s AICD']
test1
# Out:
#                                 Number of members  Total visits  \
# Distance from Melbourne's AICD
# (0, 5]                                        174          5551
# (5, 10]                                       369         11597
# (10, 15]                                      385         12289
# (15, 20]                                      235          8352
# (20, 25]                                      119          3258
# (25, 35]                                       69          2257
# (35, 50]                                        3           152
#
#                                 Avg meeting time  Avg visits
# Distance from Melbourne's AICD
# (0, 5]                                130.522989   31.902299
# (5, 10]                               133.154472   31.428184
# (10, 15]                              143.187013   31.919481
# (15, 20]                              131.974468   35.540426
# (20, 25]                              138.487395   27.378151
# (25, 35]                              136.521739   32.710145
# (35, 50]                              141.666667   50.666667

# %%
fig, ax = plt.subplots(figsize=(16,12))
plt.scatter(hq_melb['longitude'], hq_melb['latitude'], s=hq_melb['total_visits'], alpha=0.6,label='Members headquarters')
plt.scatter(-37.817007400214266, 144.96252718190436, s=120,label='AICD Melbourne Lounge')
plt.axis('off')
plt.title('Plot 14: Distance from lounge vs total visits in Melbourne')
plt.legend()
plt.show()

# %% [markdown]
# ## Perth

# %%
x1 = hq_perth.groupby(pd.cut(hq_perth.perth_distance, bins))['avg_dwell_time_in_min'].count()
x2 = hq_perth.groupby(pd.cut(hq_perth.perth_distance, bins))['total_visits'].sum()
x3 = hq_perth.groupby(pd.cut(hq_perth.perth_distance, bins))['avg_dwell_time_in_min'].mean()
test1 = pd.concat([x1,x2,x3],axis=1)
test1.columns = ['Number of members','Total visits','Avg meeting time']
test1['Avg visits'] = test1['Total visits'] / test1['Number of members']
test1.index.names = ['Distance from Perth\'s AICD']
test1
# Out:
#                             Number of members  Total visits  Avg meeting time  \
# Distance from Perth's AICD
# (0, 5]                                    121          4610        126.165289
# (5, 10]                                   315         10827        128.730159
# (10, 15]                                  248         10131        138.379032
# (15, 20]                                  194          6599        132.597938
# (20, 25]                                  103          3632        124.485437
# (25, 35]                                   46          1251        141.108696
# (35, 50]                                    7           346        140.428571
#
#                             Avg visits
# Distance from Perth's AICD
# (0, 5]                       38.099174
# (5, 10]                      34.371429
# (10, 15]                     40.850806
# (15, 20]                     34.015464
# (20, 25]                     35.262136
# (25, 35]                     27.195652
# (35, 50]                     49.428571

# %%
fig, ax = plt.subplots(figsize=(16,12))
plt.scatter(hq_perth['longitude'], hq_perth['latitude'], s=hq_perth['total_visits'], alpha=0.6,label='Members headquarters')
plt.scatter(-31.955110587081872, 115.85829166015982, s=120,label='AICD Perth Lounge')
plt.axis('off')
plt.title('Plot 15: Distance from lounge vs total visits in Perth')
plt.legend()
plt.show()

# %% [markdown]
# We can notice some minor changes in average meeting time or the amount of average visits, but there's no clear correlation.
# **Only the members with headquarters furthest from AICD lounge present different numbers, but their sample size is always too small to draw any conclusions.**
#
# # Final conclusions:
# * Sydney is the dominant lounge, attracting members from other cities, local members have the highest average number of visits to their local lounge and the lowest number of visits outside of their city
# * Melbourne is the only city, where members are more likely to visit a lounge in a different city, than their own
#     * When visiting Sydney or Perth they usually come from industries not popular in the Melbourne lounge
# * AICD has a lot of CEOs as members (overall 36% of members are CEOs), yet they rarely visit any lounges
# * Both in Sydney and Perth, Chairs are responsible for majority of visits both local and outside of their city,
#     * In Melbourne's case, it's the Non-Executive Directors who generate the highest number of visits both locally and in other cities
# * Distance of members company headquarters doesn't have an effect on their amount of visits or average visit time to the local AICD lounge

# %%
# %%html
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
# Out:
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
