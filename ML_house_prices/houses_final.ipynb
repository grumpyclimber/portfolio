# %% [markdown]
# # Predicting house prices with linear regression
#
# This is my second machine learning notebook, we're going to use linear regression model to predict house prices. This is a very basic version of ML models as I'm still learning and this project is a part of an ongoing Dataquest course. This doesn't mean that I can't go beyond the scope of this lesson, some of the concepts I've touched in this notebook:
# * feature engineering (eg. merging multiple columns into one, adding or multiplying the quality values)
# * outlier removal (compared 2 basic methods: iqr score and z score)
# * overfitting (isolated a test set that I've only used at the very end of this notebook)
#
# As you'll notice more and more processing is being done inside functions - this helps to reduce memory usage, though saving on memory wasn't an important feature of this project ( I've just started a longer project on that matter [here](https://github.com/grumpyclimber/portfolio/tree/main/taxis_big_ML) ).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from sklearn import linear_model
from sklearn.model_selection import KFold
from itertools import combinations
from sklearn.feature_selection import SelectKBest, f_classif
from scipy import stats
import missingno as msno

# %% [markdown]
# **Links:**
# * [Dataset](https://github.com/grumpyclimber/portfolio/blob/main/ML_house_prices/AmesHousing.tsv)
# * [My Github](https://github.com/grumpyclimber/portfolio)
# * [My LinkedIn](https://www.linkedin.com/in/adam-kubalica-787a79220/)
#
# **Articles:**
# * [Feature engineering](https://www.kaggle.com/c/home-data-for-ml-course/discussion/100526#652503)
# * [Outliers removal](https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba)
# * [Overfitting](https://machinelearningmastery.com/overfitting-and-underfitting-with-machine-learning-algorithms/)
# * [memory usage](https://www.kaggle.com/pavansanagapati/14-simple-tips-to-save-ram-memory-for-1-gb-dataset#Technique-10:-Memory-leaks)
#
# <a id='index'></a>
#
# ## Index:
# 1. [Initial inspection](#start)
# 2. [Basic pipeline](#basic)
# 3. [Outliers removal](#outliers)
# 4. [Feature engineering](#feng)
# 5. [Data noise](#noise)
# 6. [Overfitting](#over)
# 7. [Extreme errors](#error)
# 8. [Conclusions](#end)

# %% [markdown]
# <a id='start'></a>

# %% [markdown]
# # 1. Inital inspection

# %%
df = pd.read_csv('AmesHousing.tsv', delimiter="\t")
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0        0       5    2010       WD           Normal     215000
# 1        0       6    2010       WD           Normal     105000
# 2    12500       6    2010       WD           Normal     172000
# 3        0       4    2010       WD           Normal     244000
# 4        0       3    2010       WD           Normal     189900
#
# [5 rows x 82 columns]

# %%
msno.matrix(df)
plt.show()

# %% [markdown]
# ### Split the data:
# ### - Create 2  datasets, that we're going to use onwards: 'train' and 'test'
# ### - Create an isolated dataset for testing at the very end

# %%
df = pd.read_csv('AmesHousing.tsv', delimiter="\t")
# lets create a dataset that, we're not going to use till the very end:
df_end_test = df[2000:]
# the remaining dataset will be split into 2 sets: train and test:
df = df[:2000]
train = df[:1000].copy()
test = df[1000:].copy()
df.isnull().sum().sort_values(ascending=False)[:10]
# Out:
# Pool QC          1995
# Misc Feature     1918
# Alley            1857
# Fence            1616
# Fireplace Qu      967
# Lot Frontage      344
# Garage Cond       104
# Garage Finish     104
# Garage Yr Blt     104
# Garage Qual       104
# dtype: int64

# %%
# lets generate a correlation heatmap:
mask = np.triu(np.ones_like(train.corr(), dtype=bool))
fig, ax = plt.subplots(figsize=(16,16))
sns.heatmap(abs(train.corr()), square=True, cmap='BrBG', mask=mask)
plt.show()

# %% [markdown]
# ## **Observations:**
# ### - multiple columns with nominal or continuous data that can be merged into a smaller number of columns (eg. there are at least 4 columns related to 'porch')
# ### - some columns contain mostly null values (eg. Pool QC), we'll keep them for now and merge them into 1 column in the future
# ### - even though they're mostly empty, they may become an important factor in price predictions

# %% [markdown]
# <a id='basic'></a>

# %% [markdown]
# # 2. Setting up a basic pipeline
# [back to top](#index)

# %%
def transform_features2(df):
    # remove string columns with empty values:
    null_count = df.select_dtypes(include=['object']).isnull().sum()
    textic2_drop = null_count[null_count > 0].index
    df = df.drop(textic2_drop,axis=1) 
    # remove numeric columns with null values proportion higher than 5%
    null_count = (df.isnull().sum() / len(df))
    df = df[null_count[null_count<0.05].index]
    df = df.fillna(df.select_dtypes(include=['integer','float']).mean())

    # drop the year col and other data-leaky cols:
    cols_to_drop = ['Garage Yr Blt', "Year Remod/Add", 'Yr Sold', 'PID', "Order", 'Sale Type', 'Sale Condition',"Mo Sold"]
    for el in cols_to_drop:
        if el in df.columns:
            df = df.drop(el, axis = 1)
    return df

def select_features2(df_train, df_test):
    # check correlation of columns with SalePrice in TRAIN set (test set kind of "doesn't" have that column):
    abs_corr_coeffs = df_train.corr()['SalePrice'].abs().sort_values(ascending=False)
    # choose best(most correlated) columns in train set and trimm down both datasets to those columns:
    cols = abs_corr_coeffs[abs_corr_coeffs > 0.4].index.tolist()
    df_train = df_train[cols]
    df_test = df_test[cols]
    return df_train, df_test

def train_and_test(train, test): 
    # choose numeric columns:
    numeric_train = train.select_dtypes(include=['integer','float'])
    numeric_test = test.select_dtypes(include=['integer','float'])
    
    # train
    features = numeric_train.columns.drop("SalePrice")
    lr = linear_model.LinearRegression()
    lr.fit(train[features], train["SalePrice"])
    predictions = lr.predict(test[features])
    mse = mean_squared_error(test["SalePrice"], predictions)
    rmse = np.sqrt(mse)
    return rmse, predictions

# lets create a pipeline function, so  we can just replace names of the input functions to test out the new changes
def pipeline(df_train=train, df_test=test , t=transform_features2, s=select_features2, r=train_and_test):
    transform_train = t(df_train)
    transform_test = t(df_test)
    selected_train, selected_test = s(transform_train, transform_test)
    rmse, predictions = r(selected_train, selected_test)
    return rmse, predictions
r, p = pipeline()
r
# Out:
# 38210.67417866206

# %% [markdown]
# ### Inital rmse value is 38210.67, our aim is to drive this value down as much as possible.

# %% [markdown]
# # 2.1. Improving feature selection and column dummies

# %%
train = df[:1000].copy()
test = df[1000:].copy()

# dummy columns function:
def col_dummy(df, col):
    df[col] = df[col].astype('category')
    df[col] = df[col].cat.codes
    hood_series = pd.get_dummies(df[col],prefix=col)
    df = pd.concat([df, hood_series], axis=1)
    df = df.drop(columns=(col), axis=1)
    return df

categorical_no_leaks = [ "MS SubClass", "MS Zoning", "Street", "Alley", "Land Contour", "Lot Config", "Neighborhood", 
                    "Condition 1", "Condition 2", "Bldg Type", "House Style", "Roof Style", "Roof Matl", "Exterior 1st", 
                    "Exterior 2nd", "Mas Vnr Type", "Foundation", "Heating", "Central Air", "Garage Type", 
                    "Misc Feature"]

categorical_no_leaks2 = []

# check which categorical columns have more than 10 value_counts, pass them on for hot encoding:
for col in categorical_no_leaks: 
    if (col in df.columns) & (df[col].value_counts().shape[0]>10):
        categorical_no_leaks2.append(col)

def select_features3(df_train,df_test, corr=0.1): 
    # check correlation of columns with SalePrice in TRAIN set (test set kind of "doesn't" have that column):   
    abs_corr_coeffs = df_train.corr()['SalePrice'].abs().sort_values(ascending=False)
     # choose best(most correlated) columns in train set and trimm down both datasets to those columns:
    cols = abs_corr_coeffs[abs_corr_coeffs > corr].index.tolist()
    df_train2 = df_train[cols].copy()
    df_test2 = df_test[cols].copy()
    #hot encoding:
    for col in categorical_no_leaks2:
        if col in df.columns:
            df_train2[col] = df_train[col]
            df_test2[col] = df_test[col]           
            df_train2 = col_dummy(df_train,col)
            df_test2 = col_dummy(df_test,col)         
    return df_train, df_test

r, p = pipeline(df_train=train, df_test=test, s=select_features3)
r
# Out:
# 36854.046594920386

# %%
# lets create a function for tweaking plots:
def spines(ax,yl='Price',xl='Gr Liv Area',title='No title!'):
    x1 = ax.spines['right'].set_visible(False)
    x2 = ax.spines['top'].set_visible(False)
    x3 = ax.spines['left'].set_linewidth(2)
    x4 = ax.spines['bottom'].set_linewidth(2)
    x5 = ax.set_ylabel(yl)
    x6 = ax.set_xlabel(xl)
    x7 = ax.set_title(title)
    return x1, x2, x3, x4, x5, x6

# %%
# create a function for scatter plot results:
def scatter_results(df, p):
    # sort the dataset by SalePrice:
    df['predicted'] = p
    df = df.sort_values('SalePrice')
    df = df.reset_index()
    df = df.drop(columns='index')

    x1 = plt.scatter(df.index, df['SalePrice'], s=30, label='SalePrice', alpha=0.5)
    x2 = plt.scatter(df.index, df['predicted'], s=30, label='Predicted price', alpha=0.5)

    handles, labels = ax.get_legend_handles_labels()
    l = plt.legend(handles, labels, loc=2, borderaxespad=0)
    for el in l.legendHandles:
        el._sizes = [40]
    x3 = handles, labels, l
    return  x1, x2, x3

fig, ax = plt.subplots(figsize=(16,8))
scatter_results(test,p) 
spines(ax,yl='price',xl='index', title='Predcition results')
# arrows:
ax.annotate("extreme error", xy=(460, 800000), xytext=(200, 500000), arrowprops=dict(arrowstyle="->"))
ax.annotate("limit of accurate predictions", xy=(990, 500000), xytext=(500, 500000), arrowprops=dict(arrowstyle="->"))    

plt.show()

# %% [markdown]
# ### **Observations:**
# ### - One very big and extreme error is having a huge impact on our rmse results
# ### - We can notice, that towards the right side of chart, as the price increses, the prediction values can't keep up with the price icrease

# %% [markdown]
# ### Lets inspect that one extreme results:

# %%
test.sort_values('predicted',ascending=False)[:1]
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1498   1499  908154235           60        RL         313.0     63887   Pave
#
#      Alley Lot Shape Land Contour  ... Pool QC Fence Misc Feature Misc Val  \
# 1498   NaN       IR3          Bnk  ...      Gd   NaN          NaN        0
#
#      Mo Sold Yr Sold Sale Type Sale Condition  SalePrice     predicted
# 1498       1    2008       New        Partial     160000  824829.99499
#
# [1 rows x 83 columns]

# %%
abs_corr_coeffs = train.corr()['SalePrice'].abs().sort_values(ascending=False)
cols = abs_corr_coeffs[abs_corr_coeffs > 0.4].index.tolist()
biggest_rmse_index = test.sort_values('predicted',ascending=False)[:1].index.values[0]
test[cols].loc[biggest_rmse_index] / test[cols].mean()
# Out:
# SalePrice          0.860035
# Overall Qual       1.609788
# Gr Liv Area        3.730231
# Total Bsmt SF      5.698988
# 1st Flr SF         4.012472
# Garage Cars        1.111111
# Garage Area        2.947412
# Year Built         1.017819
# Garage Yr Blt      1.014351
# Year Remod/Add     1.011070
# Full Bath          1.253133
# BsmtFin SF 1      12.700087
# Mas Vnr Area       6.827161
# TotRms AbvGrd      1.859600
# Fireplaces         5.110733
# dtype: float64

# %% [markdown]
# ### 1 extreme prediction results in a very big increase of a rmse results, we can see that this entry has some unusual values, just to select a few:
#
# |Value| Anomaly|
# |---|---|
# |'Gr Liv Area'|        3.7 times bigger than average|
# | 'Total Bsmt SF'|      5.7 times bigger than average|
# | '1st Flr SF'|         4 times bigger than average|
# | 'BsmtFin SF 1'|      12 times bigger than average|
#
# ### Seems like we need to remove outliers in the dataset to improve our model.

# %% [markdown]
# <a id='outliers'></a>

# %% [markdown]
# # 3. Outliers removal
# [back to top](#index)
#
# In this part we'll try to improve the model by removing extreme values in certain columns, those extreme values create a noise that's not digested very well by our model. First we'll decide on the method we're going to use. Then we're going to use that method on a few columns. There are many outlier removal techniques, we'll just focus on the simplest 2: IQR score and z score.
#
# Interested in outlier removal? [read this article](https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba)

# %%
train = df[:1000].copy()
test = df[1000:].copy()

def iqring(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    df2 = df[~((df[col] < (Q1 - 1.5 * IQR)) |(df[col] > (Q3 + 1.5 * IQR)))]
    return df2

# IQR
train_iqr = iqring(train,'Gr Liv Area' )
test_iqr = iqring(test,'Gr Liv Area' )

# Z score
z = np.abs(stats.zscore(train['Gr Liv Area']))
threshold = 3
np.where(z > 3)
train_z = train[(z < 3)]
z = np.abs(stats.zscore(test['Gr Liv Area']))
threshold = 3
np.where(z > 3)
test_z = test[(z < 3)]

iqr_rmse, p = pipeline(df_train=train_iqr, df_test=test_iqr, s=select_features3)
z_score_rmse, p = pipeline(df_train=train_z, df_test=test_z, s=select_features3)
print('RMSE results:')
print('Original dataset: ',r,'   IQR: ',iqr_rmse,'   Z score: ',z_score_rmse)

def scatter(df1, df2):
    x1 = plt.scatter(df1['Gr Liv Area'], df1['SalePrice'], s=25, alpha=0.7)
    x2 = plt.scatter(df2['Gr Liv Area'], df2['SalePrice'], s=25, alpha=0.7)
    plt.legend(['Train set','Test set'])
    return x1, x2

fig, ax = plt.subplots(figsize=(16,16))
grid = plt.GridSpec(3, 1, wspace=0.4, hspace=0.3)

ax1 = plt.subplot(grid[0, 0])
scatter(train, test)

ax2 = plt.subplot(grid[1, 0])
scatter(train_iqr, test_iqr)

ax3 = plt.subplot(grid[2, 0])
scatter(train_z, test_z)

spines(ax1, title='Orignal dataset'), spines(ax2, title='IQR-score'), spines(ax3, title='Z-score')
for ax in [ax1, ax2, ax3]:
    ax.set_xlim(0,6000)
    ax.set_ylim(0,800000)
plt.show()
# Out:
# RMSE results:
# Original dataset:  36854.046594920386    IQR:  27414.72052922669    Z score:  28277.375376245913

# %% [markdown]
# **Observations:**
#
# The initial datasets contain multiple extreme outliers, both z-score and iqr-score method remove them and the right side of the plot is empty. Lets compare the rmse numbers after applying those methods in 10 random runs:

# %%
original_results = []
iqr_results = []
z_results = []
df2 = df.copy()
for num in list(range(1,11)):
    np.random.seed(num)
    shuffled_index = np.random.permutation(df2.index)
    df2 = df2.reindex(index = shuffled_index)
    split_loc = int(0.5*len(df2))
    # split
    train_rand = df2.iloc[:split_loc].copy()
    test_rand  = df2.iloc[split_loc:].copy()
    train_iqr = iqring(train_rand,'Gr Liv Area' )
    test_iqr = iqring(test_rand,'Gr Liv Area' )

    # Z score
    z = np.abs(stats.zscore(train_rand['Gr Liv Area']))
    threshold = 3
    np.where(z > 3)
    train_z = train_rand[(z < 3)]
    z = np.abs(stats.zscore(test_rand['Gr Liv Area']))
    threshold = 3
    np.where(z > 3)
    test_z = test_rand[(z < 3)]

    rmse, p = pipeline(df_train=train_rand, df_test=test_rand, s=select_features3)
    original_results.append(rmse)
    iqr_rmse, p = pipeline(df_train=train_iqr, df_test=test_iqr, s=select_features3)
    iqr_results.append(iqr_rmse)
    z_score_rmse, p = pipeline(df_train=train_z, df_test=test_z, s=select_features3)
    z_results.append(z_score_rmse)
nums = list(range(1,11))
fig, ax = plt.subplots(figsize=(16,8))
plt.scatter(nums, original_results, label='Original dataset', s=250, alpha=0.7)
plt.scatter(nums, z_results, label='Z-score outlier removal', s=250, alpha=0.7)
plt.scatter(nums, iqr_results, label='IQR-score outlier removal', s=250, alpha=0.7)
spines(ax,xl='Random seed', yl='RMSE', title='Outlier removal comparison: 10 random seeds')
plt.legend()
plt.show()

# %%
print('Original dataset avg rmse results:',np.mean(original_results))
print('Dataset with z-score outlier removal:', np.mean(z_results))
print('Dataset with iqr-score outlier removal:',np.mean(iqr_results))
# Out:
# Original dataset avg rmse results: 34520.38303004007
# Dataset with z-score outlier removal: 28366.63298514278
# Dataset with iqr-score outlier removal: 26895.80625874908

# %%
len(train)
# Out:
# 1000

# %%
len(train_iqr)
# Out:
# 979

# %% [markdown]
# ## **IQR score generates the best results.**
# ### - We'll continue on with removing outliers using IQR score method.
# ### - It's worth remembering that every round of outlier removal reduces the size of the dataset. (we've removed outliers in one column and the dataframe shrunk by 21 rows)

# %% [markdown]
# <a id='feng'></a>

# %% [markdown]
# # 4. Feature engineering
# [back to top](#index)
#
# At this stage we'll commence a subtle art of feature engineering, the best guidance I've found online is an [article](https://towardsdatascience.com/feature-engineering-and-ensembled-models-for-the-top-10-in-kaggle-housing-prices-competition-efb35828eef0) on towardsdatascience. To quote a very important section from his article:
#
# >Combining data / simplifying the model — that’s what I use a lot. The world is not that complicated. In this case, it seems to me that 3 features would be enough — how big the house is?, how nice it is? how comfortable is it?
#
# (The above link leads to an article on towardsdatascience.com, link to original post: [link](https://www.kaggle.com/c/home-data-for-ml-course/discussion/100526#652503))

# %% [markdown]
# <a id='feng1'></a>

# %% [markdown]
# # 4.1. Feature engineering part 1.
#
# Combining data seems like an easy option - lets try it. We'll merge columns in a few different ways, for now lets start with an easy merging of features and their quality. We can see a repetitive pattern in some columns:
# * numeric column with an amount (or area) of features (eg. number of kitchens or garage area)
# * categorical column with quality of features (quality scale: 'Po', 'Fa', 'TA', 'Gd', 'Ex')
# * we'll transform the quality column into numbers and multiply it by the amount of features
#     * while doing that will raise the quality number to a power of our own deciding (the idea is: quality of kitchen should be more important and price influencing than the quality of garage)

# %%
len(train.columns)
# Out:
# 82

# %%
def quality_area(data2,phrase,col1,col2, weight):
    # look up all 'keyword' columns:
    phrase_cols = [col for col in data2.columns if phrase in col]
    data2['quality'] = data2[col1].map({None: 1, "Po": 2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6})
    # change nulls to 1:
    data2.loc[data2["quality"].isnull(), "quality"] = 1
    data2[phrase+'_all'] = data2[col2] * (data2["quality"]**weight)
    data2 = data2.drop(columns=phrase_cols+["quality"], axis=1)
    return data2

def merge_cols(df):
    # Now lets use this function to merge all columns that relate to:
    # 1. fireplace
    df = quality_area(df,'Fireplace','Fireplace Qu','Fireplaces',5)
    # 2. kitchen:
    df = quality_area(df,'Kitchen','Kitchen Qual','Kitchen AbvGr',7)
    # 3. garage
    df = quality_area(df,'Garage','Garage Cond','Garage Area',1)
#     4. pool and... - lets try adding one more column to 'Pool_all' column
    df = quality_area(df,'Pool','Pool QC','Pool Area',1)
    df['Pool_all'] = df['Pool_all']+df['Misc Val']
    df = df.drop(columns=['Misc Val'])
    return df

train = df[:1000].copy()
test = df[1000:].copy()
# remove outliers:
train = iqring(train,'Gr Liv Area' )
test = iqring(test,'Gr Liv Area' )
# feature engineering:
train = merge_cols(train)
test = merge_cols(test)

iqr_rmse, p = pipeline(df_train=train, df_test=test, s=select_features3)
iqr_rmse
# Out:
# 25716.60076718674

# %% [markdown]
# **Feature engineering continues:**
# * merging bathrooms
# * merging porch area from multiple porch columns and wood deck column
# * multiplying 'Gr Liv Area' and 'Overall Qual' and saving the value into 1 column

# %%
def merge_cols2(df):
    # bathrooms:
    df['bath_count'] = df['Full Bath']**3 + (df['Half Bath']) + df['Bsmt Full Bath'] + df['Bsmt Half Bath']
    df = df.drop(columns=['Full Bath', 'Half Bath', 'Bsmt Full Bath', 'Bsmt Half Bath'], axis=1)

    # porch
    porch_cols = [col for col in df.columns if 'Porch' in col]
    df['total_porch'] = df[porch_cols].sum(axis=1) + df['Wood Deck SF']
    df= df.drop(columns=porch_cols+['Wood Deck SF'], axis=1)
    # merge 2 columns that are highly correlated with 'SalePrice'
    df['livin_qa'] = (df['Gr Liv Area'] ) * (df["Overall Qual"]) 
    df = df.drop(columns=['Gr Liv Area',"Overall Qual"], axis=1)
    # remove "Lot cols":
    lot_cols = [col for col in df.columns if 'Lot' in col]
    df= df.drop(columns=lot_cols, axis=1)
    return df

train = df[:1000].copy()
test = df[1000:].copy()
# remove outliers
train = iqring(train,'Gr Liv Area' )
test = iqring(test,'Gr Liv Area' )
# feature engineering:
train = merge_cols(train)
test = merge_cols(test)
train = merge_cols2(train)
test = merge_cols2(test)

rmse, p = pipeline(df_train=train, df_test=test, s=select_features3)
rmse
# Out:
# 24084.738986915392

# %% [markdown]
# <a id='feng2'></a>

# %% [markdown]
# # 4.2. Feature engineering part 2.
#
# After doing the first part of feature engineering our rmse results lowered - we're on the right track. We'll continue with a modified approach. General idea stays the same: merge multiple columns related to the same topic into 1 column (call it captain planet). However it gets a bit trickier at this stage:
#
# * they're categorical columns so we can't just add or multiply their values
# * instead we'll group the dataset by the current column(eg.'Roof Style') and get average house price values per roof style
#     * we'll do the same for every 'roof' column
#     * then we'll either add or multiply all those values to create one unified 'roof' column
#     * we'll repeat the process for other features
#     * it's important to pay attention to type of columns - mapping columns with continuos values would create data leaks
#     * we'll only group and get average price values in the training set - remember that test set **"doesn't"** have price values

# %%
categorical_no_leaks2 = ['MS SubClass', 'Neighborhood']

def merging_data(df,cols_list):
    d_list = []
    for el in cols_list:
        d = df.groupby(el)['SalePrice'].mean().sort_values().to_dict()
        d_list.append(d)
    return d_list, cols_list

def merge_cols3(train, test):

    # Roof: 
    dl,dl1 = merging_data(train, ['Roof Style', 'Roof Matl'])
    train['roofs'] = train['Roof Style'].map(dl[0]) + train['Roof Matl'].map(dl[1])**2
    test['roofs'] = test['Roof Style'].map(dl[0]) + test['Roof Matl'].map(dl[1])**2
    
    # street: 
    dl,dl2 = merging_data(train, ['Street', 'Alley', 'Paved Drive'])
    train['streets'] = train['Street'].map(dl[0]) + train['Alley'].map(dl[1]) + train['Paved Drive'].map(dl[2])
    test['streets'] = test['Street'].map(dl[0]) + test['Alley'].map(dl[1]) + test['Paved Drive'].map(dl[2])
   
    # basement:
    dl,dl3 = merging_data(train, ['Bsmt Qual','Bsmt Exposure','Bsmt Cond'])
    train['base_all'] = (train['Bsmt Qual'].map(dl[0]) + train['Bsmt Exposure'].map(dl[1]) + train['Bsmt Cond'].map(dl[2])) * train['Total Bsmt SF']
    test['base_all'] = (test['Bsmt Qual'].map(dl[0]) + test['Bsmt Exposure'].map(dl[1]) + test['Bsmt Cond'].map(dl[2])) * test['Total Bsmt SF']
   
    # exterior:
    dl,dl4 = merging_data(train, ['Exter Qual', 'Exter Cond', 'Exterior 1st', 'Exterior 2nd', 
                                'Mas Vnr Type', 'Foundation'])
    train['exterior'] = (train['Exter Qual'].map(dl[0])*2 + train['Exter Cond'].map(dl[1]) + train['Exterior 1st'].map(dl[2]) 
    + train['Exterior 2nd'].map(dl[3]) + train['Foundation'].map(dl[5]) + train['Mas Vnr Type'].map(dl[4])) * train['Mas Vnr Area']  
    test['exterior'] = (test['Exter Qual'].map(dl[0])*2 + test['Exter Cond'].map(dl[1]) + test['Exterior 1st'].map(dl[2]) 
    + test['Exterior 2nd'].map(dl[3]) + test['Foundation'].map(dl[5]) + test['Mas Vnr Type'].map(dl[4])) * test['Mas Vnr Area']  
    
    # heating, AC
    dl, dl5 = merging_data(train, ['Heating', 'Heating QC', 'Central Air'])
    train['heating'] = train['Heating'].map(dl[0]) + train['Heating QC'].map(dl[1]) + train['Central Air'].map(dl[2])
    test['heating'] = test['Heating'].map(dl[0]) + test['Heating QC'].map(dl[1]) + test['Central Air'].map(dl[2])
    
    land_cols = [col for col in df.columns if 'Land' in col]
    dl,dl6 = merging_data(train, land_cols)
    train['land_all'] = train[land_cols[0]].map(dl[0]) + train[land_cols[1]].map(dl[1])
    test['land_all'] = test[land_cols[0]].map(dl[0]) + test[land_cols[1]].map(dl[1])

    train = train.drop(columns=dl1 + dl2 + dl3 + dl4 + dl5 + dl6 + ['Mas Vnr Area', 'Total Bsmt SF' ])
    test = test.drop(columns=dl1 + dl2 + dl3 + dl4 + dl5 + dl6 + ['Mas Vnr Area', 'Total Bsmt SF' ])
    return train, test

train = df[:1000].copy()
test = df[1000:].copy()
# remove outliers
train = iqring(train,'Gr Liv Area' )
test = iqring(test,'Gr Liv Area' )
# feature engineering:
train = merge_cols(train)
test = merge_cols(test)
train = merge_cols2(train)
test = merge_cols2(test)
train, test = merge_cols3(train, test)
rmse, p = pipeline(df_train=train, df_test=test, s=select_features3)
rmse
# Out:
# 22654.03815744211

# %%
len(train.columns)
# Out:
# 45

# %% [markdown]
# ### We've made some progress, the number of columns almost halved and the rmse results have decreased.

# %% [markdown]
# <a id='noise'></a>

# %% [markdown]
# # 5. The noise
# [back to top](#index)
#
# One last thing to try is removing columns that contain data already stored in other columns. We'll plot a correlation matrix one more time, but lets not forget that before going into the ML cogs, our dataset gets filtered with a few functions. We don't have to check the whole dataset, just the columns actually going into the model at the end of the pipeline.
#
# We'll also remove outliers from our new columns that we've feature engineered in step 4.

# %%
abs_corr_coeffs = train.corr()['SalePrice'].abs().sort_values(ascending=False)
cols = abs_corr_coeffs[abs_corr_coeffs > 0.4].index.tolist()
# lets generate a correlation heatmap:
mask = np.triu(np.ones_like(train[cols].corr(), dtype=bool))
fig, ax = plt.subplots(figsize=(16,16))
sns.heatmap(abs(train[cols].corr()), square=True, cmap='BrBG', mask=mask)
plt.show()

# %%
def dropem(df1,df2, cols):
    df1 = df1.drop(columns=cols)
    df2 = df2.drop(columns=cols)
    return df1, df2

train = df[:1000].copy()
test = df[1000:].copy()

# remove outliers
train = iqring(train,'Gr Liv Area' )
test = iqring(test,'Gr Liv Area' )

# feature engineering:
train = merge_cols(train)
test = merge_cols(test)
train = merge_cols2(train)
test = merge_cols2(test)
train, test = merge_cols3(train, test)

# drop a few columns:
cols = ['TotRms AbvGrd', 'Year Remod/Add']
train, test = dropem(train, test, cols)

# remove outliers from new columns:
train = iqring(train,'livin_qa' )
test = iqring(test,'livin_qa' )
train = iqring(train,'BsmtFin SF 1' )
test = iqring(test,'BsmtFin SF 1' )
train = iqring(train,'1st Flr SF' )
test = iqring(test,'1st Flr SF' )

rmse, p1 = pipeline(df_train=train, df_test=test, s=select_features3)
rmse
# Out:
# 21436.11201687847

# %%
fig, ax = plt.subplots(figsize=(16,8))
scatter_results(test,p1)
spines(ax,yl='price',xl='index', title='Predcition results')
plt.show()

# %% [markdown]
# <a id='over'></a>

# %% [markdown]
# # 6. Overfitting or underfitting?
# [back to top](#index)

# %% [markdown]
# I'll spare myself from trying to explain these terms, many people have done a great job at it. Here's an article with good explanation:
# [article](https://machinelearningmastery.com/overfitting-and-underfitting-with-machine-learning-algorithms/)
#
# To quote the important parts:
# ```
# Overfitting refers to a model that models the training data too well.
#
# Overfitting happens when a model learns the detail and noise in the training data to the extent that it
# negatively impacts the performance of the model on new data. This means that the noise or random
# fluctuations in the training data is picked up and learned as concepts by the model. The problem is
# that these concepts do not apply to new data and negatively impact the models ability to generalize.
# ```
# And how we can look for overfitting?
#
#
#
# ```
# Over time, as the algorithm learns, the error for the model on the training data goes down and so does
# the error on the test dataset. If we train for too long, the performance on the training dataset may
# continue to decrease because the model is overfitting and learning the irrelevant detail and noise in
# the training dataset. At the same time the error for the test set starts to rise again as the model’s
# ability to generalize decreases.
# ```
#
# So lets check if we haven't trained our model too much.
# **Remember that part of initial dataset that we've isolated and never used?** We've called it 'df_end_test' and it's time to use it. If we'll observe big rmse result difference between our well tested data sets and the 'df_end_test', then we'll know we haven't done a great job. The last result we've got with train and test sets was a rmse of 21436.1. Lets see what results we're going to get with 'df_end_test':

# %%
train_end = df.copy()
test_end = df_end_test.copy()
# remove outliers
train_end = iqring(train_end,'Gr Liv Area' )
test_end = iqring(test_end,'Gr Liv Area' )
# feature engineering:
train_end = merge_cols(train_end)
test_end = merge_cols(test_end)
train_end = merge_cols2(train_end)
test_end = merge_cols2(test_end)
train_end, test_end = merge_cols3(train_end, test_end)

cols = ['TotRms AbvGrd', 'Year Remod/Add']
train_end, test_end = dropem(train_end, test_end, cols)
# remove outliers from new columns:
train_end = iqring(train_end,'livin_qa' )
test_end = iqring(test_end,'livin_qa' )
train_end = iqring(train_end,'BsmtFin SF 1' )
test_end = iqring(test_end,'BsmtFin SF 1' )
train_end = iqring(train_end,'1st Flr SF' )
test_end = iqring(test_end,'1st Flr SF' )

rmse, p2 = pipeline(df_train=train_end, df_test=test_end, s=select_features3)
rmse
# Out:
# 20264.81864117655

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax = plt.subplot(121)
scatter_results(test,p1)
spines(ax,yl='Price',xl='index', title='Price predictions')
ax = plt.subplot(122)
scatter_results(test_end,p2)
spines(ax,yl='Price',xl='index', title='Price predictions on the isolated end set')
plt.show()

# %% [markdown]
# ### The result on our end dataset is close to the results we've been getting on our first sets. It's not the same, but it's close enough (~5%) !

# %% [markdown]
# <a id='error'></a>

# %% [markdown]
# # 7. Managing extreme errors
# [back to top](#index)

# %% [markdown]
# ### So is that it? We're done?
# Not quite, because **we've been removing outliers in both training and testing datasets**. What if we really were supposed to predict all the prices from the testing set? We can't remove the outliers! We'd be removing entries that we're supposed to be predicting!
# One way is to keep on removing outliers and do some manual labor in the entries that we've removed from the dataset. The other way... Lets see what happens if we don't remove the outliers from the testing set.

# %%
train_end = df.copy()
test_end = df_end_test.copy()
# remove outliers
train_end = iqring(train_end,'Gr Liv Area' )
# feature engineering:
train_end = merge_cols(train_end)
test_end = merge_cols(test_end)
train_end = merge_cols2(train_end)
test_end = merge_cols2(test_end)
train_end, test_end = merge_cols3(train_end, test_end)
cols = ['TotRms AbvGrd', 'Year Remod/Add']
train_end, test_end = dropem(train_end, test_end, cols)
# remove outliers fromm new columns:
train_end = iqring(train_end,'livin_qa' )
train_end = iqring(train_end,'BsmtFin SF 1' )
train_end = iqring(train_end,'1st Flr SF' )

rmse, p3 = pipeline(df_train=train_end, df_test=test_end, s=select_features3)
rmse
# Out:
# 35640.53151724192

# %% [markdown]
# ### That's a rather large number, lest see how it looks on a chart:

# %%
fig, ax = plt.subplots(figsize=(16,8))
scatter_results(test_end,p3)
spines(ax,yl='Price',xl='index', title='Price predictions')
plt.show()

# %% [markdown]
# ### It looks like we have 2 extreme cases of rmse error. Lets see if we could notice them in a real world scenario, where 'SalePrice' value wouldn't exist in the test dataset (we'd be predicting it).

# %%
fig, ax = plt.subplots(figsize=(16,8))
test_end['predict'] = p3
test_end = test_end.sort_values('predict', ascending=False)
test_end = test_end.reset_index()
test_end = test_end.drop(columns='index')
plt.scatter(test_end['predict'].index.tolist(),test_end['predict'], label='Predicted price')
spines(ax, title='Predcitions', xl='index', yl='predicted price')
plt.legend()
plt.show()

# %% [markdown]
# ### Can we do it without plots?

# %%
stats.zscore(test_end['predict'])
# Out:
# 0      8.820751
# 1      6.694854
# 2      4.478415
# 3      4.055054
# 4      3.991341
#          ...
# 925   -1.688773
# 926   -1.690309
# 927   -1.705168
# 928   -1.829703
# 929   -1.867363
# Name: predict, Length: 930, dtype: float64

# %% [markdown]
# ### Even without the knowledge of true 'SalePrice', the worst results of our model are very few and very extreme, it would be easy to spot them and filter them out. After that, address them individually. Lets check the rmse values without those 2 entries:

# %%
test_end = test_end.loc[2:]
mse = mean_squared_error(test_end["SalePrice"], test_end['predict'])
np.sqrt(mse)
# Out:
# 22909.931167334886

# %% [markdown]
# **Filtering out extreme errors in this dataset was an easy task**
#
# Both scatter plots clearly demonstrated 2 extreme values.
# * it is especially important that the second plot made it easy - that plot doesn't have any real 'SalePrice' information (like a real dataset wouldn't had that data)
# * this leaves us with a task of manually predicting the price for these 2 entries - which we won't do here, because we know those prices
# * after removing the mentioned 2 entries, our rmse results are back to a level close enough to previous rmse results

# %% [markdown]
# <a id='end'></a>

# %% [markdown]
# # 8. Conclusions
# [back to top](#index)
#
# * It is very important to manage extreme outliers in linear regression - their removal can have a huge impact on our results
#     * lets not forget though: real world datasets would have those values, and we should always try to create a model that works on all the data that we're being given
# * Having a high rmse doesn't necessarily mean bad model, sometimes it's just a few extreme errors that create a very high rmse value  - it's always worth double checking the predictions, lets not forget that root mean squared error has a 'mean' in its name and **mean is very sensitive to extreme values**
# * Feature engineering - it doesn't require a lot of technical coding, just common sense and some industry knowledge, and it is worth the extra effort
#     * **It is very important that person working on those features pays attention and is aware of data leaks**
# * during this project I've also tested a few new solutions that haven't been included in this notebook (trying not to make it too long like [my first ML notebook](https://github.com/grumpyclimber/portfolio/tree/main/ML_intro_car_prices)) :
#     * SimpleImputer - Imputation transformer for completing missing values from scikit-learn library
#     * SelectKBest - function for selecting features according to the k highest scores
#     * Feature Extraction with RFE and PCA
#     * It was my first time testing out those functions and for the purpose of this simple dataset they seemed like a bit of an overkill. Nevertheless they're clearly great tools and I'll start using them in future projects as the datasets grow in size and complexity
#     * I've also testes out numpy log transformation, which can have a significant improvement on our results
